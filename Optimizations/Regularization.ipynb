# %% [markdown]
# # **⬇️ Import Libraries**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import cv2
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras import regularizers
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras import models,layers

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import random
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import torch
from torch import nn
import os
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
import cv2
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras import regularizers
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras import models,layers

from keras import models, layers, regularizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import CategoricalCrossentropy

# %%
# Path to the folder containing the numbered images
image_folder = '/content/drive/MyDrive/Leaf images'

# Path to the CSV file
csv_file_path = '/content/drive/MyDrive/train.csv'

# Read the CSV file
df = pd.read_csv(csv_file_path)

# Function to load and parse images
def load_images_and_labels(image_folder, df, max_size=(1620, 1050), target_size=(244,244)):
    data = []
    labels = []

    for index, row in df.iterrows():
        image_id = row['id']
        species = row['species']

        # Construct the image file path based on the ID
        image_path = os.path.join(image_folder, f"{image_id}.jpg")

        # Load the image using OpenCV in grayscale mode
        #image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)


        # Resize the image to the max size with replicated padding
        height, width = image.shape
        new_height, new_width = max_size

        # Calculate padding
        pad_height = max(0, (new_height - height) // 2)
        pad_width = max(0, (new_width - width) // 2)

        # Replicate padding
        image = cv2.copyMakeBorder(image, pad_height, pad_height, pad_width, pad_width, cv2.BORDER_REPLICATE)


        # Resize the image to the target size
        new_height, new_width = target_size

        image = cv2.resize(image, (new_width, new_height))

        # Convert OpenCV image to TensorFlow tensor
        numpy_array = np.array(image)

         # Append the image and label to the lists
        data.append(numpy_array)
        labels.append(species)

    return data,labels

# Load images and labels
images,labels = load_images_and_labels(image_folder, df, max_size=(1620, 1050), target_size=(244,244))

# %%
updated_labels = np.array(labels)
updated_images= np.array(images)

# %%
print(updated_images.shape)
print(updated_labels.shape)
# Out:
# (990, 244, 244)
# (990,)

# %%
updated_images= updated_images.reshape(len(updated_images),244,244,1)
updated_labels= updated_labels.reshape(len(updated_labels),1)

# %%
print(updated_images.shape)
print(updated_labels.shape)
# Out:
# (990, 244, 244, 1)
# (990, 1)

# %%
LabelEncoder  = preprocessing.LabelEncoder()
LabelEncoder.fit(updated_labels)
num_labels = LabelEncoder.transform(updated_labels)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %% [markdown]
# ### **Try different Optimizers**

# %%
from keras import regularizers

# List of regularizers and their corresponding regularization values to try
regularizers_values = [('l1', [0.001, 0.01, 0.1]), ('l2', [0.001, 0.01, 0.1]), ('l1_l2', [0.001, 0.01, 0.1])]

# Dictionary to store accuracy results for each regularizer
accuracy_results = {}

# Iterate through each regularizer and its regularization values
for regularizer, regularization_values in regularizers_values:
    for regularization_value in regularization_values:
        network = models.Sequential()


        # First Convolutional layer with (3,3) matrix size, same padding refers to add additional columns or rows to align
        # with the filter and a maxpooling layers which takes maximum value in the (3,3) pixel value matrix.
        network.add(layers.Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(244, 244, 1)))
        network.add(layers.MaxPool2D((2,2)))  # Reduced the pool size to (2,2) to reduce aggressive downsampling
        network.add(layers.Dropout(0.15))

        # Second convolutional layer with 64 filters
        network.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
        network.add(layers.MaxPool2D((2,2)))
        network.add(layers.Dropout(0.15))

        # Third convolutional layer with 128 filters
        network.add(layers.Conv2D(128, (3,3), padding='same', activation='relu'))
        network.add(layers.MaxPool2D((2,2)))
        network.add(layers.Dropout(0.15))

        # Fourth convolutional layer with 256 filters
        network.add(layers.Conv2D(256, (3,3), padding='same', activation='relu'))
        network.add(layers.MaxPool2D((2,2)))
        network.add(layers.Dropout(0.15))

        # Flatten layer
        network.add(layers.Flatten())

        # Dense layer of 512 neurons with ReLU activation function and regularizer
        if regularizer == 'l1':
            reg = regularizers.l1(regularization_value)
        elif regularizer == 'l2':
            reg = regularizers.l2(regularization_value)
        elif regularizer == 'l1_l2':
            reg = regularizers.l1_l2(l1=regularization_value, l2=regularization_value)
        network.add(layers.Dense(512, activation='relu', kernel_regularizer=reg))
        network.add(layers.Dropout(0.15))

        # Final Dense Layer with number of neurons same as number of classes of classification and 'softmax' as the
        # activation function
        network.add(layers.Dense(99, activation='softmax'))

        # Compile the model with Adam optimizer
        network.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
        X_train, X_test, Y_train, Y_test = train_test_split(updated_images, num_labels, test_size=0.2, random_state=5, shuffle=True)

        Y_train_one_hot = to_categorical(Y_train, num_classes = 99)

        # Print network summary to check the layer shapes
        print(network.summary())
        # Train the model
        history = network.fit(X_train, Y_train_one_hot, epochs=50, batch_size=32, verbose=1)

        # Store the accuracy results for the current regularizer and regularization value
        accuracy_results[(regularizer, regularization_value)] = history.history['accuracy']
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_84 (Conv2D)          (None, 244, 244, 32)      320
#
#  max_pooling2d_84 (MaxPooli  (None, 122, 122, 32)      0
#  ng2D)
#
#  dropout_105 (Dropout)       (None, 122, 122, 32)      0
#
#  conv2d_85 (Conv2D)          (None, 122, 122, 64)      18496
#
#  max_pooling2d_85 (MaxPooli  (None, 61, 61, 64)        0
#  ng2D)
#
#  dropout_106 (Dropout)       (None, 61, 61, 64)        0
#
#  conv2d_86 (Conv2D)          (None, 61, 61, 128)       73856
#
#  max_pooling2d_86 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  dropout_107 (Dropout)       (None, 30, 30, 128)       0
#
#  conv2d_87 (Conv2D)          (None, 30, 30, 256)       295168
#
#  max_pooling2d_87 (MaxPooli  (None, 15, 15, 256)       0
#  ng2D)
#
#  dropout_108 (Dropout)       (None, 15, 15, 256)       0
#
#  flatten_21 (Flatten)        (None, 57600)             0
#
#  dense_42 (Dense)            (None, 512)               29491712
#
#  dropout_109 (Dropout)       (None, 512)               0
#
#  dense_43 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 25/25 [==============================] - 5s 106ms/step - loss: 107.3400 - accuracy: 0.0518
# Epoch 2/50
# 25/25 [==============================] - 3s 106ms/step - loss: 55.8240 - accuracy: 0.2563
# Epoch 3/50
# 25/25 [==============================] - 3s 107ms/step - loss: 40.7439 - accuracy: 0.4280
# Epoch 4/50
# 25/25 [==============================] - 3s 105ms/step - loss: 31.6854 - accuracy: 0.5429
# Epoch 5/50
# 25/25 [==============================] - 3s 105ms/step - loss: 25.6583 - accuracy: 0.5732
# Epoch 6/50
# 25/25 [==============================] - 3s 105ms/step - loss: 21.4194 - accuracy: 0.6414
# Epoch 7/50
# 25/25 [==============================] - 3s 107ms/step - loss: 18.2576 - accuracy: 0.6414
# Epoch 8/50
# 25/25 [==============================] - 3s 106ms/step - loss: 15.7088 - accuracy: 0.6944
# Epoch 9/50
# 25/25 [==============================] - 3s 105ms/step - loss: 13.7813 - accuracy: 0.7083
# Epoch 10/50
# 25/25 [==============================] - 3s 105ms/step - loss: 12.1881 - accuracy: 0.7298
# Epoch 11/50
# 25/25 [==============================] - 3s 105ms/step - loss: 10.9196 - accuracy: 0.7753
# Epoch 12/50
# 25/25 [==============================] - 3s 106ms/step - loss: 9.8482 - accuracy: 0.7891
# Epoch 13/50
# 25/25 [==============================] - 3s 106ms/step - loss: 8.9091 - accuracy: 0.8056
# Epoch 14/50
# 25/25 [==============================] - 3s 106ms/step - loss: 8.2791 - accuracy: 0.8030
# Epoch 15/50
# 25/25 [==============================] - 3s 105ms/step - loss: 7.7755 - accuracy: 0.8106
# Epoch 16/50
# 25/25 [==============================] - 3s 105ms/step - loss: 7.3027 - accuracy: 0.8422
# Epoch 17/50
# 25/25 [==============================] - 3s 107ms/step - loss: 6.8372 - accuracy: 0.8624
# Epoch 18/50
# 25/25 [==============================] - 3s 105ms/step - loss: 6.4050 - accuracy: 0.8674
# Epoch 19/50
# 25/25 [==============================] - 3s 104ms/step - loss: 6.0538 - accuracy: 0.8649
# Epoch 20/50
# 25/25 [==============================] - 3s 104ms/step - loss: 5.8425 - accuracy: 0.8712
# Epoch 21/50
# 25/25 [==============================] - 3s 105ms/step - loss: 5.7498 - accuracy: 0.8712
# Epoch 22/50
# 25/25 [==============================] - 3s 107ms/step - loss: 5.3829 - accuracy: 0.8939
# Epoch 23/50
# 25/25 [==============================] - 3s 105ms/step - loss: 5.3348 - accuracy: 0.8699
# Epoch 24/50
# 25/25 [==============================] - 3s 105ms/step - loss: 5.2070 - accuracy: 0.8838
# Epoch 25/50
# 25/25 [==============================] - 3s 105ms/step - loss: 5.0942 - accuracy: 0.8775
# Epoch 26/50
# 25/25 [==============================] - 3s 106ms/step - loss: 4.8149 - accuracy: 0.9217
# Epoch 27/50
# 25/25 [==============================] - 3s 107ms/step - loss: 4.6919 - accuracy: 0.9192
# Epoch 28/50
# 25/25 [==============================] - 3s 105ms/step - loss: 4.8165 - accuracy: 0.8813
# Epoch 29/50
# 25/25 [==============================] - 3s 104ms/step - loss: 4.7538 - accuracy: 0.9104
# Epoch 30/50
# 25/25 [==============================] - 3s 104ms/step - loss: 4.6951 - accuracy: 0.9053
# Epoch 31/50
# 25/25 [==============================] - 3s 110ms/step - loss: 4.6742 - accuracy: 0.9015
# Epoch 32/50
# 25/25 [==============================] - 3s 119ms/step - loss: 4.5927 - accuracy: 0.9205
# Epoch 33/50
# 25/25 [==============================] - 3s 105ms/step - loss: 4.5395 - accuracy: 0.9129
# Epoch 34/50
# 25/25 [==============================] - 3s 105ms/step - loss: 4.5534 - accuracy: 0.9015
# Epoch 35/50
# 25/25 [==============================] - 3s 105ms/step - loss: 4.4811 - accuracy: 0.9179
# Epoch 36/50
# 25/25 [==============================] - 3s 106ms/step - loss: 4.5443 - accuracy: 0.9104
# Epoch 37/50
# 25/25 [==============================] - 3s 107ms/step - loss: 4.4370 - accuracy: 0.9242
# Epoch 38/50
# 25/25 [==============================] - 3s 104ms/step - loss: 4.3207 - accuracy: 0.9407
# Epoch 39/50
# 25/25 [==============================] - 3s 104ms/step - loss: 4.3287 - accuracy: 0.9205
# Epoch 40/50
# 25/25 [==============================] - 3s 105ms/step - loss: 4.1805 - accuracy: 0.9470
# Epoch 41/50
# 25/25 [==============================] - 3s 105ms/step - loss: 4.1495 - accuracy: 0.9318
# Epoch 42/50
# 25/25 [==============================] - 3s 106ms/step - loss: 4.1845 - accuracy: 0.9167
# Epoch 43/50
# 25/25 [==============================] - 3s 105ms/step - loss: 4.2473 - accuracy: 0.9230
# Epoch 44/50
# 25/25 [==============================] - 3s 104ms/step - loss: 4.2375 - accuracy: 0.9343
# Epoch 45/50
# 25/25 [==============================] - 3s 105ms/step - loss: 4.3131 - accuracy: 0.9280
# Epoch 46/50
# 25/25 [==============================] - 3s 106ms/step - loss: 4.2251 - accuracy: 0.9482
# Epoch 47/50
# 25/25 [==============================] - 3s 106ms/step - loss: 4.3271 - accuracy: 0.9306
# Epoch 48/50
# 25/25 [==============================] - 3s 105ms/step - loss: 4.1923 - accuracy: 0.9558
# Epoch 49/50
# 25/25 [==============================] - 3s 105ms/step - loss: 4.2509 - accuracy: 0.9508
# Epoch 50/50
# 25/25 [==============================] - 3s 105ms/step - loss: 4.2886 - accuracy: 0.9242
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_88 (Conv2D)          (None, 244, 244, 32)      320
#
#  max_pooling2d_88 (MaxPooli  (None, 122, 122, 32)      0
#  ng2D)
#
#  dropout_110 (Dropout)       (None, 122, 122, 32)      0
#
#  conv2d_89 (Conv2D)          (None, 122, 122, 64)      18496
#
#  max_pooling2d_89 (MaxPooli  (None, 61, 61, 64)        0
#  ng2D)
#
#  dropout_111 (Dropout)       (None, 61, 61, 64)        0
#
#  conv2d_90 (Conv2D)          (None, 61, 61, 128)       73856
#
#  max_pooling2d_90 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  dropout_112 (Dropout)       (None, 30, 30, 128)       0
#
#  conv2d_91 (Conv2D)          (None, 30, 30, 256)       295168
#
#  max_pooling2d_91 (MaxPooli  (None, 15, 15, 256)       0
#  ng2D)
#
#  dropout_113 (Dropout)       (None, 15, 15, 256)       0
#
#  flatten_22 (Flatten)        (None, 57600)             0
#
#  dense_44 (Dense)            (None, 512)               29491712
#
#  dropout_114 (Dropout)       (None, 512)               0
#
#  dense_45 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 25/25 [==============================] - 5s 108ms/step - loss: 621.2144 - accuracy: 0.0391
# Epoch 2/50
# 25/25 [==============================] - 3s 105ms/step - loss: 168.6901 - accuracy: 0.1503
# Epoch 3/50
# 25/25 [==============================] - 3s 105ms/step - loss: 74.7829 - accuracy: 0.2866
# Epoch 4/50
# 25/25 [==============================] - 3s 105ms/step - loss: 49.4145 - accuracy: 0.3586
# Epoch 5/50
# 25/25 [==============================] - 3s 108ms/step - loss: 41.7380 - accuracy: 0.4343
# Epoch 6/50
# 25/25 [==============================] - 3s 106ms/step - loss: 39.3790 - accuracy: 0.4684
# Epoch 7/50
# 25/25 [==============================] - 3s 105ms/step - loss: 38.5836 - accuracy: 0.4747
# Epoch 8/50
# 25/25 [==============================] - 3s 105ms/step - loss: 38.3079 - accuracy: 0.5114
# Epoch 9/50
# 25/25 [==============================] - 3s 106ms/step - loss: 38.2757 - accuracy: 0.5391
# Epoch 10/50
# 25/25 [==============================] - 3s 108ms/step - loss: 38.1082 - accuracy: 0.5379
# Epoch 11/50
# 25/25 [==============================] - 3s 106ms/step - loss: 38.2604 - accuracy: 0.5404
# Epoch 12/50
# 25/25 [==============================] - 3s 106ms/step - loss: 38.3772 - accuracy: 0.5404
# Epoch 13/50
# 25/25 [==============================] - 3s 106ms/step - loss: 38.2224 - accuracy: 0.6149
# Epoch 14/50
# 25/25 [==============================] - 3s 106ms/step - loss: 38.2358 - accuracy: 0.6073
# Epoch 15/50
# 25/25 [==============================] - 3s 107ms/step - loss: 38.2785 - accuracy: 0.6187
# Epoch 16/50
# 25/25 [==============================] - 3s 106ms/step - loss: 38.3852 - accuracy: 0.6376
# Epoch 17/50
# 25/25 [==============================] - 3s 106ms/step - loss: 38.4085 - accuracy: 0.6414
# Epoch 18/50
# 25/25 [==============================] - 3s 106ms/step - loss: 38.1394 - accuracy: 0.6818
# Epoch 19/50
# 25/25 [==============================] - 3s 107ms/step - loss: 38.2865 - accuracy: 0.6705
# Epoch 20/50
# 25/25 [==============================] - 3s 108ms/step - loss: 38.4205 - accuracy: 0.6679
# Epoch 21/50
# 25/25 [==============================] - 3s 106ms/step - loss: 38.3403 - accuracy: 0.6869
# Epoch 22/50
# 25/25 [==============================] - 3s 107ms/step - loss: 38.2725 - accuracy: 0.7083
# Epoch 23/50
# 25/25 [==============================] - 3s 107ms/step - loss: 38.2057 - accuracy: 0.7096
# Epoch 24/50
# 25/25 [==============================] - 3s 108ms/step - loss: 38.2714 - accuracy: 0.7071
# Epoch 25/50
# 25/25 [==============================] - 3s 107ms/step - loss: 38.4212 - accuracy: 0.6995
# Epoch 26/50
# 25/25 [==============================] - 3s 106ms/step - loss: 38.4746 - accuracy: 0.7058
# Epoch 27/50
# 25/25 [==============================] - 3s 106ms/step - loss: 38.1455 - accuracy: 0.7033
# Epoch 28/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.9364 - accuracy: 0.7601
# Epoch 29/50
# 25/25 [==============================] - 3s 108ms/step - loss: 37.9007 - accuracy: 0.7626
# Epoch 30/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.9629 - accuracy: 0.7412
# Epoch 31/50
# 25/25 [==============================] - 3s 106ms/step - loss: 38.3545 - accuracy: 0.7449
# Epoch 32/50
# 25/25 [==============================] - 3s 106ms/step - loss: 38.3066 - accuracy: 0.7639
# Epoch 33/50
# 25/25 [==============================] - 3s 106ms/step - loss: 38.2100 - accuracy: 0.7563
# Epoch 34/50
# 25/25 [==============================] - 3s 108ms/step - loss: 38.0791 - accuracy: 0.7765
# Epoch 35/50
# 25/25 [==============================] - 3s 106ms/step - loss: 38.1096 - accuracy: 0.7803
# Epoch 36/50
# 25/25 [==============================] - 3s 105ms/step - loss: 38.2696 - accuracy: 0.7803
# Epoch 37/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.9912 - accuracy: 0.7765
# Epoch 38/50
# 25/25 [==============================] - 3s 106ms/step - loss: 38.1663 - accuracy: 0.7614
# Epoch 39/50
# 25/25 [==============================] - 3s 107ms/step - loss: 38.3135 - accuracy: 0.7551
# Epoch 40/50
# 25/25 [==============================] - 3s 105ms/step - loss: 38.1376 - accuracy: 0.7955
# Epoch 41/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.8592 - accuracy: 0.8005
# Epoch 42/50
# 25/25 [==============================] - 3s 105ms/step - loss: 37.7510 - accuracy: 0.7929
# Epoch 43/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.9428 - accuracy: 0.7816
# Epoch 44/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.6080 - accuracy: 0.8510
# Epoch 45/50
# 25/25 [==============================] - 3s 105ms/step - loss: 37.8834 - accuracy: 0.7917
# Epoch 46/50
# 25/25 [==============================] - 3s 105ms/step - loss: 38.0419 - accuracy: 0.8245
# Epoch 47/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.9084 - accuracy: 0.8157
# Epoch 48/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.8626 - accuracy: 0.8207
# Epoch 49/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.6341 - accuracy: 0.8510
# Epoch 50/50
# 25/25 [==============================] - 3s 105ms/step - loss: 37.6509 - accuracy: 0.8283
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_92 (Conv2D)          (None, 244, 244, 32)      320
#
#  max_pooling2d_92 (MaxPooli  (None, 122, 122, 32)      0
#  ng2D)
#
#  dropout_115 (Dropout)       (None, 122, 122, 32)      0
#
#  conv2d_93 (Conv2D)          (None, 122, 122, 64)      18496
#
#  max_pooling2d_93 (MaxPooli  (None, 61, 61, 64)        0
#  ng2D)
#
#  dropout_116 (Dropout)       (None, 61, 61, 64)        0
#
#  conv2d_94 (Conv2D)          (None, 61, 61, 128)       73856
#
#  max_pooling2d_94 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  dropout_117 (Dropout)       (None, 30, 30, 128)       0
#
#  conv2d_95 (Conv2D)          (None, 30, 30, 256)       295168
#
#  max_pooling2d_95 (MaxPooli  (None, 15, 15, 256)       0
#  ng2D)
#
#  dropout_118 (Dropout)       (None, 15, 15, 256)       0
#
#  flatten_23 (Flatten)        (None, 57600)             0
#
#  dense_46 (Dense)            (None, 512)               29491712
#
#  dropout_119 (Dropout)       (None, 512)               0
#
#  dense_47 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 25/25 [==============================] - 5s 107ms/step - loss: 4317.2583 - accuracy: 0.0379
# Epoch 2/50
# 25/25 [==============================] - 3s 107ms/step - loss: 753.7631 - accuracy: 0.0682
# Epoch 3/50
# 25/25 [==============================] - 3s 107ms/step - loss: 426.4753 - accuracy: 0.1452
# Epoch 4/50
# 25/25 [==============================] - 3s 105ms/step - loss: 384.8827 - accuracy: 0.2045
# Epoch 5/50
# 25/25 [==============================] - 3s 106ms/step - loss: 378.6494 - accuracy: 0.2576
# Epoch 6/50
# 25/25 [==============================] - 3s 105ms/step - loss: 378.3609 - accuracy: 0.2475
# Epoch 7/50
# 25/25 [==============================] - 3s 108ms/step - loss: 378.0872 - accuracy: 0.2740
# Epoch 8/50
# 25/25 [==============================] - 3s 106ms/step - loss: 376.5894 - accuracy: 0.3207
# Epoch 9/50
# 25/25 [==============================] - 3s 106ms/step - loss: 377.5632 - accuracy: 0.3093
# Epoch 10/50
# 25/25 [==============================] - 3s 106ms/step - loss: 375.5293 - accuracy: 0.3169
# Epoch 11/50
# 25/25 [==============================] - 3s 106ms/step - loss: 375.2633 - accuracy: 0.3359
# Epoch 12/50
# 25/25 [==============================] - 3s 109ms/step - loss: 374.6339 - accuracy: 0.3548
# Epoch 13/50
# 25/25 [==============================] - 3s 105ms/step - loss: 374.8899 - accuracy: 0.3775
# Epoch 14/50
# 25/25 [==============================] - 3s 106ms/step - loss: 374.3397 - accuracy: 0.3573
# Epoch 15/50
# 25/25 [==============================] - 3s 106ms/step - loss: 374.1223 - accuracy: 0.3699
# Epoch 16/50
# 25/25 [==============================] - 3s 106ms/step - loss: 373.0180 - accuracy: 0.4015
# Epoch 17/50
# 25/25 [==============================] - 3s 108ms/step - loss: 372.1679 - accuracy: 0.4015
# Epoch 18/50
# 25/25 [==============================] - 3s 106ms/step - loss: 372.7509 - accuracy: 0.4230
# Epoch 19/50
# 25/25 [==============================] - 3s 106ms/step - loss: 373.0468 - accuracy: 0.4432
# Epoch 20/50
# 25/25 [==============================] - 3s 106ms/step - loss: 371.5205 - accuracy: 0.4381
# Epoch 21/50
# 25/25 [==============================] - 3s 107ms/step - loss: 371.4373 - accuracy: 0.4495
# Epoch 22/50
# 25/25 [==============================] - 3s 108ms/step - loss: 371.0207 - accuracy: 0.4520
# Epoch 23/50
# 25/25 [==============================] - 3s 105ms/step - loss: 370.5102 - accuracy: 0.4912
# Epoch 24/50
# 25/25 [==============================] - 3s 106ms/step - loss: 370.1993 - accuracy: 0.4609
# Epoch 25/50
# 25/25 [==============================] - 3s 106ms/step - loss: 370.2415 - accuracy: 0.4937
# Epoch 26/50
# 25/25 [==============================] - 3s 107ms/step - loss: 370.0834 - accuracy: 0.5202
# Epoch 27/50
# 25/25 [==============================] - 3s 107ms/step - loss: 369.7647 - accuracy: 0.4975
# Epoch 28/50
# 25/25 [==============================] - 3s 106ms/step - loss: 369.0302 - accuracy: 0.5253
# Epoch 29/50
# 25/25 [==============================] - 3s 106ms/step - loss: 368.7878 - accuracy: 0.5202
# Epoch 30/50
# 25/25 [==============================] - 3s 106ms/step - loss: 368.2432 - accuracy: 0.4937
# Epoch 31/50
# 25/25 [==============================] - 3s 109ms/step - loss: 368.6098 - accuracy: 0.5480
# Epoch 32/50
# 25/25 [==============================] - 3s 107ms/step - loss: 368.3187 - accuracy: 0.5316
# Epoch 33/50
# 25/25 [==============================] - 3s 106ms/step - loss: 367.8234 - accuracy: 0.5227
# Epoch 34/50
# 25/25 [==============================] - 3s 106ms/step - loss: 367.5934 - accuracy: 0.5467
# Epoch 35/50
# 25/25 [==============================] - 3s 106ms/step - loss: 366.9683 - accuracy: 0.5518
# Epoch 36/50
# 25/25 [==============================] - 3s 109ms/step - loss: 367.1471 - accuracy: 0.5808
# Epoch 37/50
# 25/25 [==============================] - 3s 106ms/step - loss: 366.6792 - accuracy: 0.5694
# Epoch 38/50
# 25/25 [==============================] - 3s 106ms/step - loss: 367.2954 - accuracy: 0.5821
# Epoch 39/50
# 25/25 [==============================] - 3s 106ms/step - loss: 367.4473 - accuracy: 0.6086
# Epoch 40/50
# 25/25 [==============================] - 3s 106ms/step - loss: 366.4079 - accuracy: 0.5821
# Epoch 41/50
# 25/25 [==============================] - 3s 108ms/step - loss: 366.2193 - accuracy: 0.5783
# Epoch 42/50
# 25/25 [==============================] - 3s 106ms/step - loss: 365.1270 - accuracy: 0.6010
# Epoch 43/50
# 25/25 [==============================] - 3s 106ms/step - loss: 366.3678 - accuracy: 0.6061
# Epoch 44/50
# 25/25 [==============================] - 3s 106ms/step - loss: 365.2325 - accuracy: 0.6086
# Epoch 45/50
# 25/25 [==============================] - 3s 107ms/step - loss: 365.1263 - accuracy: 0.6212
# Epoch 46/50
# 25/25 [==============================] - 3s 108ms/step - loss: 364.7239 - accuracy: 0.6124
# Epoch 47/50
# 25/25 [==============================] - 3s 106ms/step - loss: 363.7389 - accuracy: 0.6250
# Epoch 48/50
# 25/25 [==============================] - 3s 106ms/step - loss: 364.9481 - accuracy: 0.6124
# Epoch 49/50
# 25/25 [==============================] - 3s 106ms/step - loss: 364.2869 - accuracy: 0.6427
# Epoch 50/50
# 25/25 [==============================] - 3s 108ms/step - loss: 363.4930 - accuracy: 0.6477
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_96 (Conv2D)          (None, 244, 244, 32)      320
#
#  max_pooling2d_96 (MaxPooli  (None, 122, 122, 32)      0
#  ng2D)
#
#  dropout_120 (Dropout)       (None, 122, 122, 32)      0
#
#  conv2d_97 (Conv2D)          (None, 122, 122, 64)      18496
#
#  max_pooling2d_97 (MaxPooli  (None, 61, 61, 64)        0
#  ng2D)
#
#  dropout_121 (Dropout)       (None, 61, 61, 64)        0
#
#  conv2d_98 (Conv2D)          (None, 61, 61, 128)       73856
#
#  max_pooling2d_98 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  dropout_122 (Dropout)       (None, 30, 30, 128)       0
#
#  conv2d_99 (Conv2D)          (None, 30, 30, 256)       295168
#
#  max_pooling2d_99 (MaxPooli  (None, 15, 15, 256)       0
#  ng2D)
#
#  dropout_123 (Dropout)       (None, 15, 15, 256)       0
#
#  flatten_24 (Flatten)        (None, 57600)             0
#
#  dense_48 (Dense)            (None, 512)               29491712
#
#  dropout_124 (Dropout)       (None, 512)               0
#
#  dense_49 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 25/25 [==============================] - 5s 105ms/step - loss: 17.3502 - accuracy: 0.0328
# Epoch 2/50
# 25/25 [==============================] - 3s 102ms/step - loss: 3.9527 - accuracy: 0.2235
# Epoch 3/50
# 25/25 [==============================] - 3s 101ms/step - loss: 2.7265 - accuracy: 0.4533
# Epoch 4/50
# 25/25 [==============================] - 3s 102ms/step - loss: 2.1215 - accuracy: 0.5745
# Epoch 5/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.8464 - accuracy: 0.6515
# Epoch 6/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.6002 - accuracy: 0.7348
# Epoch 7/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.3849 - accuracy: 0.7917
# Epoch 8/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.2293 - accuracy: 0.8194
# Epoch 9/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.0934 - accuracy: 0.8636
# Epoch 10/50
# 25/25 [==============================] - 3s 103ms/step - loss: 0.9582 - accuracy: 0.8939
# Epoch 11/50
# 25/25 [==============================] - 3s 102ms/step - loss: 0.9277 - accuracy: 0.8965
# Epoch 12/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.8590 - accuracy: 0.9293
# Epoch 13/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.8676 - accuracy: 0.9179
# Epoch 14/50
# 25/25 [==============================] - 3s 103ms/step - loss: 0.7918 - accuracy: 0.9394
# Epoch 15/50
# 25/25 [==============================] - 3s 104ms/step - loss: 0.7568 - accuracy: 0.9457
# Epoch 16/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.7220 - accuracy: 0.9596
# Epoch 17/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.7149 - accuracy: 0.9545
# Epoch 18/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.7241 - accuracy: 0.9508
# Epoch 19/50
# 25/25 [==============================] - 3s 102ms/step - loss: 0.7576 - accuracy: 0.9394
# Epoch 20/50
# 25/25 [==============================] - 3s 103ms/step - loss: 0.6610 - accuracy: 0.9672
# Epoch 21/50
# 25/25 [==============================] - 3s 100ms/step - loss: 0.6520 - accuracy: 0.9621
# Epoch 22/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.6250 - accuracy: 0.9684
# Epoch 23/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.6184 - accuracy: 0.9735
# Epoch 24/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.5795 - accuracy: 0.9773
# Epoch 25/50
# 25/25 [==============================] - 3s 104ms/step - loss: 0.5747 - accuracy: 0.9798
# Epoch 26/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.5858 - accuracy: 0.9773
# Epoch 27/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.5556 - accuracy: 0.9747
# Epoch 28/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.6007 - accuracy: 0.9646
# Epoch 29/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.5708 - accuracy: 0.9747
# Epoch 30/50
# 25/25 [==============================] - 3s 105ms/step - loss: 0.5348 - accuracy: 0.9760
# Epoch 31/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.6070 - accuracy: 0.9684
# Epoch 32/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.5672 - accuracy: 0.9722
# Epoch 33/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.5248 - accuracy: 0.9697
# Epoch 34/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.5122 - accuracy: 0.9811
# Epoch 35/50
# 25/25 [==============================] - 3s 102ms/step - loss: 0.5215 - accuracy: 0.9785
# Epoch 36/50
# 25/25 [==============================] - 3s 100ms/step - loss: 0.4899 - accuracy: 0.9785
# Epoch 37/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.4837 - accuracy: 0.9848
# Epoch 38/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.4583 - accuracy: 0.9886
# Epoch 39/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.4390 - accuracy: 0.9874
# Epoch 40/50
# 25/25 [==============================] - 3s 103ms/step - loss: 0.4288 - accuracy: 0.9899
# Epoch 41/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.4866 - accuracy: 0.9811
# Epoch 42/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.4900 - accuracy: 0.9811
# Epoch 43/50
# 25/25 [==============================] - 3s 100ms/step - loss: 0.4759 - accuracy: 0.9798
# Epoch 44/50
# 25/25 [==============================] - 3s 100ms/step - loss: 0.4289 - accuracy: 0.9874
# Epoch 45/50
# 25/25 [==============================] - 3s 103ms/step - loss: 0.4327 - accuracy: 0.9823
# Epoch 46/50
# 25/25 [==============================] - 3s 102ms/step - loss: 0.4130 - accuracy: 0.9899
# Epoch 47/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.4361 - accuracy: 0.9785
# Epoch 48/50
# 25/25 [==============================] - 3s 100ms/step - loss: 0.4695 - accuracy: 0.9710
# Epoch 49/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.4145 - accuracy: 0.9886
# Epoch 50/50
# 25/25 [==============================] - 3s 104ms/step - loss: 0.4288 - accuracy: 0.9861
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_100 (Conv2D)         (None, 244, 244, 32)      320
#
#  max_pooling2d_100 (MaxPool  (None, 122, 122, 32)      0
#  ing2D)
#
#  dropout_125 (Dropout)       (None, 122, 122, 32)      0
#
#  conv2d_101 (Conv2D)         (None, 122, 122, 64)      18496
#
#  max_pooling2d_101 (MaxPool  (None, 61, 61, 64)        0
#  ing2D)
#
#  dropout_126 (Dropout)       (None, 61, 61, 64)        0
#
#  conv2d_102 (Conv2D)         (None, 61, 61, 128)       73856
#
#  max_pooling2d_102 (MaxPool  (None, 30, 30, 128)       0
#  ing2D)
#
#  dropout_127 (Dropout)       (None, 30, 30, 128)       0
#
#  conv2d_103 (Conv2D)         (None, 30, 30, 256)       295168
#
#  max_pooling2d_103 (MaxPool  (None, 15, 15, 256)       0
#  ing2D)
#
#  dropout_128 (Dropout)       (None, 15, 15, 256)       0
#
#  flatten_25 (Flatten)        (None, 57600)             0
#
#  dense_50 (Dense)            (None, 512)               29491712
#
#  dropout_129 (Dropout)       (None, 512)               0
#
#  dense_51 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 25/25 [==============================] - 4s 104ms/step - loss: 27.3291 - accuracy: 0.0543
# Epoch 2/50
# 25/25 [==============================] - 3s 101ms/step - loss: 9.2470 - accuracy: 0.2753
# Epoch 3/50
# 25/25 [==============================] - 3s 103ms/step - loss: 7.3083 - accuracy: 0.4874
# Epoch 4/50
# 25/25 [==============================] - 3s 103ms/step - loss: 6.2433 - accuracy: 0.5619
# Epoch 5/50
# 25/25 [==============================] - 3s 102ms/step - loss: 5.4027 - accuracy: 0.6629
# Epoch 6/50
# 25/25 [==============================] - 3s 101ms/step - loss: 4.7994 - accuracy: 0.6944
# Epoch 7/50
# 25/25 [==============================] - 3s 101ms/step - loss: 4.2437 - accuracy: 0.7361
# Epoch 8/50
# 25/25 [==============================] - 3s 103ms/step - loss: 3.8959 - accuracy: 0.7449
# Epoch 9/50
# 25/25 [==============================] - 3s 102ms/step - loss: 3.4594 - accuracy: 0.8169
# Epoch 10/50
# 25/25 [==============================] - 3s 101ms/step - loss: 3.1671 - accuracy: 0.8346
# Epoch 11/50
# 25/25 [==============================] - 3s 102ms/step - loss: 3.0057 - accuracy: 0.8447
# Epoch 12/50
# 25/25 [==============================] - 3s 102ms/step - loss: 2.7770 - accuracy: 0.8674
# Epoch 13/50
# 25/25 [==============================] - 3s 103ms/step - loss: 2.5496 - accuracy: 0.8826
# Epoch 14/50
# 25/25 [==============================] - 3s 103ms/step - loss: 2.3390 - accuracy: 0.8927
# Epoch 15/50
# 25/25 [==============================] - 3s 102ms/step - loss: 2.2229 - accuracy: 0.8965
# Epoch 16/50
# 25/25 [==============================] - 3s 102ms/step - loss: 2.0604 - accuracy: 0.9091
# Epoch 17/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.9601 - accuracy: 0.9053
# Epoch 18/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.9066 - accuracy: 0.9091
# Epoch 19/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.7608 - accuracy: 0.9255
# Epoch 20/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.7023 - accuracy: 0.9217
# Epoch 21/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.6409 - accuracy: 0.9280
# Epoch 22/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.5801 - accuracy: 0.9306
# Epoch 23/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.4639 - accuracy: 0.9331
# Epoch 24/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.3737 - accuracy: 0.9533
# Epoch 25/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.3265 - accuracy: 0.9381
# Epoch 26/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.3097 - accuracy: 0.9343
# Epoch 27/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.3041 - accuracy: 0.9280
# Epoch 28/50
# 25/25 [==============================] - 3s 105ms/step - loss: 1.3211 - accuracy: 0.9217
# Epoch 29/50
# 25/25 [==============================] - 3s 105ms/step - loss: 1.1936 - accuracy: 0.9432
# Epoch 30/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.1522 - accuracy: 0.9495
# Epoch 31/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.1107 - accuracy: 0.9432
# Epoch 32/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.1122 - accuracy: 0.9432
# Epoch 33/50
# 25/25 [==============================] - 3s 105ms/step - loss: 1.1974 - accuracy: 0.9394
# Epoch 34/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.1037 - accuracy: 0.9533
# Epoch 35/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.0556 - accuracy: 0.9520
# Epoch 36/50
# 25/25 [==============================] - 3s 103ms/step - loss: 0.9960 - accuracy: 0.9571
# Epoch 37/50
# 25/25 [==============================] - 3s 103ms/step - loss: 0.9236 - accuracy: 0.9697
# Epoch 38/50
# 25/25 [==============================] - 3s 105ms/step - loss: 0.8742 - accuracy: 0.9710
# Epoch 39/50
# 25/25 [==============================] - 3s 104ms/step - loss: 0.8872 - accuracy: 0.9596
# Epoch 40/50
# 25/25 [==============================] - 3s 103ms/step - loss: 0.8516 - accuracy: 0.9609
# Epoch 41/50
# 25/25 [==============================] - 3s 103ms/step - loss: 0.7946 - accuracy: 0.9747
# Epoch 42/50
# 25/25 [==============================] - 3s 103ms/step - loss: 0.8022 - accuracy: 0.9621
# Epoch 43/50
# 25/25 [==============================] - 3s 105ms/step - loss: 0.8514 - accuracy: 0.9495
# Epoch 44/50
# 25/25 [==============================] - 3s 104ms/step - loss: 0.8792 - accuracy: 0.9457
# Epoch 45/50
# 25/25 [==============================] - 3s 102ms/step - loss: 0.8113 - accuracy: 0.9520
# Epoch 46/50
# 25/25 [==============================] - 3s 103ms/step - loss: 0.7908 - accuracy: 0.9583
# Epoch 47/50
# 25/25 [==============================] - 3s 103ms/step - loss: 0.7458 - accuracy: 0.9735
# Epoch 48/50
# 25/25 [==============================] - 3s 104ms/step - loss: 0.7775 - accuracy: 0.9571
# Epoch 49/50
# 25/25 [==============================] - 3s 103ms/step - loss: 0.9801 - accuracy: 0.9306
# Epoch 50/50
# 25/25 [==============================] - 3s 102ms/step - loss: 0.9898 - accuracy: 0.9545
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_104 (Conv2D)         (None, 244, 244, 32)      320
#
#  max_pooling2d_104 (MaxPool  (None, 122, 122, 32)      0
#  ing2D)
#
#  dropout_130 (Dropout)       (None, 122, 122, 32)      0
#
#  conv2d_105 (Conv2D)         (None, 122, 122, 64)      18496
#
#  max_pooling2d_105 (MaxPool  (None, 61, 61, 64)        0
#  ing2D)
#
#  dropout_131 (Dropout)       (None, 61, 61, 64)        0
#
#  conv2d_106 (Conv2D)         (None, 61, 61, 128)       73856
#
#  max_pooling2d_106 (MaxPool  (None, 30, 30, 128)       0
#  ing2D)
#
#  dropout_132 (Dropout)       (None, 30, 30, 128)       0
#
#  conv2d_107 (Conv2D)         (None, 30, 30, 256)       295168
#
#  max_pooling2d_107 (MaxPool  (None, 15, 15, 256)       0
#  ing2D)
#
#  dropout_133 (Dropout)       (None, 15, 15, 256)       0
#
#  flatten_26 (Flatten)        (None, 57600)             0
#
#  dense_52 (Dense)            (None, 512)               29491712
#
#  dropout_134 (Dropout)       (None, 512)               0
#
#  dense_53 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 25/25 [==============================] - 4s 103ms/step - loss: 72.1270 - accuracy: 0.0404
# Epoch 2/50
# 25/25 [==============================] - 3s 104ms/step - loss: 34.1671 - accuracy: 0.2298
# Epoch 3/50
# 25/25 [==============================] - 3s 103ms/step - loss: 22.8288 - accuracy: 0.4381
# Epoch 4/50
# 25/25 [==============================] - 3s 101ms/step - loss: 16.4817 - accuracy: 0.5303
# Epoch 5/50
# 25/25 [==============================] - 3s 101ms/step - loss: 12.6179 - accuracy: 0.5821
# Epoch 6/50
# 25/25 [==============================] - 3s 102ms/step - loss: 9.9873 - accuracy: 0.6174
# Epoch 7/50
# 25/25 [==============================] - 3s 104ms/step - loss: 8.3137 - accuracy: 0.5972
# Epoch 8/50
# 25/25 [==============================] - 3s 103ms/step - loss: 6.8324 - accuracy: 0.6856
# Epoch 9/50
# 25/25 [==============================] - 3s 102ms/step - loss: 5.7168 - accuracy: 0.7096
# Epoch 10/50
# 25/25 [==============================] - 3s 102ms/step - loss: 4.8731 - accuracy: 0.7260
# Epoch 11/50
# 25/25 [==============================] - 3s 103ms/step - loss: 4.2745 - accuracy: 0.7285
# Epoch 12/50
# 25/25 [==============================] - 3s 103ms/step - loss: 3.7318 - accuracy: 0.7664
# Epoch 13/50
# 25/25 [==============================] - 3s 104ms/step - loss: 3.4366 - accuracy: 0.7437
# Epoch 14/50
# 25/25 [==============================] - 3s 103ms/step - loss: 3.0868 - accuracy: 0.7917
# Epoch 15/50
# 25/25 [==============================] - 3s 102ms/step - loss: 2.9113 - accuracy: 0.7727
# Epoch 16/50
# 25/25 [==============================] - 3s 103ms/step - loss: 2.5245 - accuracy: 0.8106
# Epoch 17/50
# 25/25 [==============================] - 3s 105ms/step - loss: 2.2763 - accuracy: 0.8283
# Epoch 18/50
# 25/25 [==============================] - 3s 104ms/step - loss: 2.1249 - accuracy: 0.8207
# Epoch 19/50
# 25/25 [==============================] - 3s 103ms/step - loss: 2.0820 - accuracy: 0.8194
# Epoch 20/50
# 25/25 [==============================] - 3s 103ms/step - loss: 2.1220 - accuracy: 0.8207
# Epoch 21/50
# 25/25 [==============================] - 3s 103ms/step - loss: 2.0973 - accuracy: 0.8270
# Epoch 22/50
# 25/25 [==============================] - 3s 105ms/step - loss: 1.8814 - accuracy: 0.8535
# Epoch 23/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.6002 - accuracy: 0.8851
# Epoch 24/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.5352 - accuracy: 0.8699
# Epoch 25/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.5422 - accuracy: 0.8460
# Epoch 26/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.6111 - accuracy: 0.8510
# Epoch 27/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.7299 - accuracy: 0.8586
# Epoch 28/50
# 25/25 [==============================] - 3s 105ms/step - loss: 1.5319 - accuracy: 0.8826
# Epoch 29/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.5709 - accuracy: 0.8523
# Epoch 30/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.4750 - accuracy: 0.8775
# Epoch 31/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.4541 - accuracy: 0.8712
# Epoch 32/50
# 25/25 [==============================] - 3s 105ms/step - loss: 1.3496 - accuracy: 0.8826
# Epoch 33/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.3150 - accuracy: 0.8977
# Epoch 34/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.4251 - accuracy: 0.8902
# Epoch 35/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.3481 - accuracy: 0.8939
# Epoch 36/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.3395 - accuracy: 0.8927
# Epoch 37/50
# 25/25 [==============================] - 3s 105ms/step - loss: 1.2715 - accuracy: 0.8977
# Epoch 38/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.2774 - accuracy: 0.8902
# Epoch 39/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.1839 - accuracy: 0.8965
# Epoch 40/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.1470 - accuracy: 0.9091
# Epoch 41/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.2194 - accuracy: 0.8927
# Epoch 42/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.3065 - accuracy: 0.8801
# Epoch 43/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.5222 - accuracy: 0.8876
# Epoch 44/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.4800 - accuracy: 0.8876
# Epoch 45/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.3721 - accuracy: 0.8990
# Epoch 46/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.2271 - accuracy: 0.9356
# Epoch 47/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.1744 - accuracy: 0.8952
# Epoch 48/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.0556 - accuracy: 0.9066
# Epoch 49/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.1251 - accuracy: 0.8851
# Epoch 50/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.1441 - accuracy: 0.8977
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_108 (Conv2D)         (None, 244, 244, 32)      320
#
#  max_pooling2d_108 (MaxPool  (None, 122, 122, 32)      0
#  ing2D)
# ...
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_112 (Conv2D)         (None, 244, 244, 32)      320
#
#  max_pooling2d_112 (MaxPool  (None, 122, 122, 32)      0
#  ing2D)
#
#  dropout_140 (Dropout)       (None, 122, 122, 32)      0
#
#  conv2d_113 (Conv2D)         (None, 122, 122, 64)      18496
#
#  max_pooling2d_113 (MaxPool  (None, 61, 61, 64)        0
#  ing2D)
#
#  dropout_141 (Dropout)       (None, 61, 61, 64)        0
#
#  conv2d_114 (Conv2D)         (None, 61, 61, 128)       73856
#
#  max_pooling2d_114 (MaxPool  (None, 30, 30, 128)       0
#  ing2D)
#
#  dropout_142 (Dropout)       (None, 30, 30, 128)       0
#
#  conv2d_115 (Conv2D)         (None, 30, 30, 256)       295168
#
#  max_pooling2d_115 (MaxPool  (None, 15, 15, 256)       0
#  ing2D)
#
#  dropout_143 (Dropout)       (None, 15, 15, 256)       0
#
#  flatten_28 (Flatten)        (None, 57600)             0
#
#  dense_56 (Dense)            (None, 512)               29491712
#
#  dropout_144 (Dropout)       (None, 512)               0
#
#  dense_57 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 25/25 [==============================] - 5s 109ms/step - loss: 655.4985 - accuracy: 0.0366
# Epoch 2/50
# 25/25 [==============================] - 3s 106ms/step - loss: 214.2022 - accuracy: 0.1111
# Epoch 3/50
# 25/25 [==============================] - 3s 106ms/step - loss: 108.2263 - accuracy: 0.2689
# Epoch 4/50
# 25/25 [==============================] - 3s 106ms/step - loss: 71.1438 - accuracy: 0.3775
# Epoch 5/50
# 25/25 [==============================] - 3s 109ms/step - loss: 55.3457 - accuracy: 0.4003
# Epoch 6/50
# 25/25 [==============================] - 3s 107ms/step - loss: 47.6467 - accuracy: 0.3876
# Epoch 7/50
# 25/25 [==============================] - 3s 106ms/step - loss: 43.3800 - accuracy: 0.4217
# Epoch 8/50
# 25/25 [==============================] - 3s 106ms/step - loss: 40.9498 - accuracy: 0.4722
# Epoch 9/50
# 25/25 [==============================] - 3s 107ms/step - loss: 39.4470 - accuracy: 0.5076
# Epoch 10/50
# 25/25 [==============================] - 3s 109ms/step - loss: 38.6053 - accuracy: 0.4937
# Epoch 11/50
# 25/25 [==============================] - 3s 107ms/step - loss: 38.2074 - accuracy: 0.5391
# Epoch 12/50
# 25/25 [==============================] - 3s 107ms/step - loss: 37.9010 - accuracy: 0.5177
# Epoch 13/50
# 25/25 [==============================] - 3s 107ms/step - loss: 37.5332 - accuracy: 0.5568
# Epoch 14/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.4064 - accuracy: 0.5455
# Epoch 15/50
# 25/25 [==============================] - 3s 109ms/step - loss: 37.2837 - accuracy: 0.6035
# Epoch 16/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.1226 - accuracy: 0.6061
# Epoch 17/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.1367 - accuracy: 0.5922
# Epoch 18/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.2690 - accuracy: 0.6048
# Epoch 19/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.0617 - accuracy: 0.6174
# Epoch 20/50
# 25/25 [==============================] - 3s 109ms/step - loss: 37.1061 - accuracy: 0.6162
# Epoch 21/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.1302 - accuracy: 0.6225
# Epoch 22/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.2458 - accuracy: 0.6465
# Epoch 23/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.2201 - accuracy: 0.6275
# Epoch 24/50
# 25/25 [==============================] - 3s 108ms/step - loss: 37.0874 - accuracy: 0.6427
# Epoch 25/50
# 25/25 [==============================] - 3s 108ms/step - loss: 37.1337 - accuracy: 0.6566
# Epoch 26/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.0898 - accuracy: 0.6591
# Epoch 27/50
# 25/25 [==============================] - 3s 105ms/step - loss: 36.9958 - accuracy: 0.6742
# Epoch 28/50
# 25/25 [==============================] - 3s 106ms/step - loss: 36.9053 - accuracy: 0.6907
# Epoch 29/50
# 25/25 [==============================] - 3s 108ms/step - loss: 37.0753 - accuracy: 0.6566
# Epoch 30/50
# 25/25 [==============================] - 3s 108ms/step - loss: 36.9548 - accuracy: 0.6982
# Epoch 31/50
# 25/25 [==============================] - 3s 106ms/step - loss: 36.8337 - accuracy: 0.6982
# Epoch 32/50
# 25/25 [==============================] - 3s 106ms/step - loss: 36.9647 - accuracy: 0.7008
# Epoch 33/50
# 25/25 [==============================] - 3s 106ms/step - loss: 36.6631 - accuracy: 0.7285
# Epoch 34/50
# 25/25 [==============================] - 3s 107ms/step - loss: 36.8991 - accuracy: 0.6970
# Epoch 35/50
# 25/25 [==============================] - 3s 107ms/step - loss: 36.7431 - accuracy: 0.7538
# Epoch 36/50
# 25/25 [==============================] - 3s 106ms/step - loss: 36.8317 - accuracy: 0.7487
# Epoch 37/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.0031 - accuracy: 0.7184
# Epoch 38/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.0346 - accuracy: 0.7285
# Epoch 39/50
# 25/25 [==============================] - 3s 108ms/step - loss: 36.8414 - accuracy: 0.7412
# Epoch 40/50
# 25/25 [==============================] - 3s 107ms/step - loss: 36.9843 - accuracy: 0.7134
# Epoch 41/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.0642 - accuracy: 0.7462
# Epoch 42/50
# 25/25 [==============================] - 3s 105ms/step - loss: 36.6979 - accuracy: 0.7386
# Epoch 43/50
# 25/25 [==============================] - 3s 106ms/step - loss: 36.6672 - accuracy: 0.7551
# Epoch 44/50
# 25/25 [==============================] - 3s 108ms/step - loss: 37.1382 - accuracy: 0.7247
# Epoch 45/50
# 25/25 [==============================] - 3s 106ms/step - loss: 37.1272 - accuracy: 0.7525
# Epoch 46/50
# 25/25 [==============================] - 3s 106ms/step - loss: 36.9972 - accuracy: 0.7689
# Epoch 47/50
# 25/25 [==============================] - 3s 106ms/step - loss: 36.9140 - accuracy: 0.7626
# Epoch 48/50
# 25/25 [==============================] - 3s 107ms/step - loss: 37.1252 - accuracy: 0.7412
# Epoch 49/50
# 25/25 [==============================] - 3s 108ms/step - loss: 36.8872 - accuracy: 0.7753
# Epoch 50/50
# 25/25 [==============================] - 3s 106ms/step - loss: 36.8147 - accuracy: 0.7790
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_116 (Conv2D)         (None, 244, 244, 32)      320
#
#  max_pooling2d_116 (MaxPool  (None, 122, 122, 32)      0
#  ing2D)
#
#  dropout_145 (Dropout)       (None, 122, 122, 32)      0
#
#  conv2d_117 (Conv2D)         (None, 122, 122, 64)      18496
#
#  max_pooling2d_117 (MaxPool  (None, 61, 61, 64)        0
#  ing2D)
#
#  dropout_146 (Dropout)       (None, 61, 61, 64)        0
#
#  conv2d_118 (Conv2D)         (None, 61, 61, 128)       73856
#
#  max_pooling2d_118 (MaxPool  (None, 30, 30, 128)       0
#  ing2D)
#
#  dropout_147 (Dropout)       (None, 30, 30, 128)       0
#
#  conv2d_119 (Conv2D)         (None, 30, 30, 256)       295168
#
#  max_pooling2d_119 (MaxPool  (None, 15, 15, 256)       0
#  ing2D)
#
#  dropout_148 (Dropout)       (None, 15, 15, 256)       0
#
#  flatten_29 (Flatten)        (None, 57600)             0
#
#  dense_58 (Dense)            (None, 512)               29491712
#
#  dropout_149 (Dropout)       (None, 512)               0
#
#  dense_59 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 25/25 [==============================] - 5s 109ms/step - loss: 4317.2974 - accuracy: 0.0265
# Epoch 2/50
# 25/25 [==============================] - 3s 107ms/step - loss: 750.2920 - accuracy: 0.0619
# Epoch 3/50
# 25/25 [==============================] - 3s 109ms/step - loss: 428.2206 - accuracy: 0.1073
# Epoch 4/50
# 25/25 [==============================] - 3s 107ms/step - loss: 390.7679 - accuracy: 0.1843
# Epoch 5/50
# 25/25 [==============================] - 3s 106ms/step - loss: 385.6987 - accuracy: 0.2298
# Epoch 6/50
# 25/25 [==============================] - 3s 106ms/step - loss: 384.4273 - accuracy: 0.2513
# Epoch 7/50
# 25/25 [==============================] - 3s 108ms/step - loss: 384.0608 - accuracy: 0.2614
# Epoch 8/50
# 25/25 [==============================] - 3s 108ms/step - loss: 382.6312 - accuracy: 0.2929
# Epoch 9/50
# 25/25 [==============================] - 3s 106ms/step - loss: 381.3463 - accuracy: 0.3030
# Epoch 10/50
# 25/25 [==============================] - 3s 106ms/step - loss: 379.9703 - accuracy: 0.3068
# Epoch 11/50
# 25/25 [==============================] - 3s 106ms/step - loss: 379.5720 - accuracy: 0.3258
# Epoch 12/50
# 25/25 [==============================] - 3s 108ms/step - loss: 378.9511 - accuracy: 0.3460
# Epoch 13/50
# 25/25 [==============================] - 3s 108ms/step - loss: 377.1806 - accuracy: 0.3447
# Epoch 14/50
# 25/25 [==============================] - 3s 107ms/step - loss: 376.5139 - accuracy: 0.3308
# Epoch 15/50
# 25/25 [==============================] - 3s 107ms/step - loss: 375.8076 - accuracy: 0.3750
# Epoch 16/50
# 25/25 [==============================] - 3s 106ms/step - loss: 373.9455 - accuracy: 0.3838
# Epoch 17/50
# 25/25 [==============================] - 3s 109ms/step - loss: 373.4260 - accuracy: 0.3788
# Epoch 18/50
# 25/25 [==============================] - 3s 107ms/step - loss: 372.9176 - accuracy: 0.4015
# Epoch 19/50
# 25/25 [==============================] - 3s 107ms/step - loss: 372.7932 - accuracy: 0.3788
# Epoch 20/50
# 25/25 [==============================] - 3s 107ms/step - loss: 371.6374 - accuracy: 0.4242
# Epoch 21/50
# 25/25 [==============================] - 3s 107ms/step - loss: 370.7513 - accuracy: 0.4571
# Epoch 22/50
# 25/25 [==============================] - 3s 109ms/step - loss: 370.5385 - accuracy: 0.4293
# Epoch 23/50
# 25/25 [==============================] - 3s 107ms/step - loss: 370.0689 - accuracy: 0.4217
# Epoch 24/50
# 25/25 [==============================] - 3s 107ms/step - loss: 369.2418 - accuracy: 0.4697
# Epoch 25/50
# 25/25 [==============================] - 3s 106ms/step - loss: 368.3230 - accuracy: 0.4508
# Epoch 26/50
# 25/25 [==============================] - 3s 108ms/step - loss: 367.2671 - accuracy: 0.4848
# Epoch 27/50
# 25/25 [==============================] - 3s 108ms/step - loss: 367.2141 - accuracy: 0.4987
# Epoch 28/50
# 25/25 [==============================] - 3s 106ms/step - loss: 366.7658 - accuracy: 0.4697
# Epoch 29/50
# 25/25 [==============================] - 3s 106ms/step - loss: 366.0608 - accuracy: 0.5038
# Epoch 30/50
# 25/25 [==============================] - 3s 106ms/step - loss: 365.8448 - accuracy: 0.4924
# Epoch 31/50
# 25/25 [==============================] - 3s 108ms/step - loss: 365.1975 - accuracy: 0.5051
# Epoch 32/50
# 25/25 [==============================] - 3s 108ms/step - loss: 363.3493 - accuracy: 0.5341
# Epoch 33/50
# 25/25 [==============================] - 3s 106ms/step - loss: 363.2791 - accuracy: 0.5139
# Epoch 34/50
# 25/25 [==============================] - 3s 107ms/step - loss: 363.7884 - accuracy: 0.5505
# Epoch 35/50
# 25/25 [==============================] - 3s 106ms/step - loss: 362.5273 - accuracy: 0.5152
# Epoch 36/50
# 25/25 [==============================] - 3s 108ms/step - loss: 362.6523 - accuracy: 0.5240
# Epoch 37/50
# 25/25 [==============================] - 3s 108ms/step - loss: 361.9589 - accuracy: 0.5631
# Epoch 38/50
# 25/25 [==============================] - 3s 106ms/step - loss: 362.3024 - accuracy: 0.5556
# Epoch 39/50
# 25/25 [==============================] - 3s 106ms/step - loss: 362.1736 - accuracy: 0.5657
# Epoch 40/50
# 25/25 [==============================] - 3s 106ms/step - loss: 361.8570 - accuracy: 0.5543
# Epoch 41/50
# 25/25 [==============================] - 3s 108ms/step - loss: 362.2888 - accuracy: 0.5997
# Epoch 42/50
# 25/25 [==============================] - 3s 107ms/step - loss: 361.6983 - accuracy: 0.5833
# Epoch 43/50
# 25/25 [==============================] - 3s 106ms/step - loss: 362.2816 - accuracy: 0.6124
# Epoch 44/50
# 25/25 [==============================] - 3s 106ms/step - loss: 361.7487 - accuracy: 0.6111
# Epoch 45/50
# 25/25 [==============================] - 3s 106ms/step - loss: 361.5687 - accuracy: 0.6073
# Epoch 46/50
# 25/25 [==============================] - 3s 109ms/step - loss: 361.2318 - accuracy: 0.6313
# Epoch 47/50
# 25/25 [==============================] - 3s 107ms/step - loss: 360.7544 - accuracy: 0.6098
# Epoch 48/50
# 25/25 [==============================] - 3s 106ms/step - loss: 361.6359 - accuracy: 0.6149
# Epoch 49/50
# 25/25 [==============================] - 3s 106ms/step - loss: 361.3730 - accuracy: 0.6098
# Epoch 50/50
# 25/25 [==============================] - 3s 106ms/step - loss: 360.8513 - accuracy: 0.6263

# %%
# Plot the accuracy results for each regularizer and regularization value
plt.figure(figsize=(10, 6))
for (regularizer, regularization_value), accuracy_values in accuracy_results.items():
    plt.plot(accuracy_values, label=f'{regularizer}_{regularization_value}')

plt.title('Accuracy Comparison for Different Regularizers and Regularization Values')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
