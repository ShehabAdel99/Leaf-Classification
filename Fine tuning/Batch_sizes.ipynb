# %% [markdown]
# # **⬇️ Import Libraries**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import cv2
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras import regularizers
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras import models,layers

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import random
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import torch
from torch import nn
import os
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
import cv2
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras import regularizers
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras import models,layers

from keras import models, layers, regularizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import CategoricalCrossentropy

# %%
# Path to the folder containing the numbered images
image_folder = '/content/drive/MyDrive/Leaf images'

# Path to the CSV file
csv_file_path = '/content/drive/MyDrive/train.csv'

# Read the CSV file
df = pd.read_csv(csv_file_path)

# Function to load and parse images
def load_images_and_labels(image_folder, df, max_size=(1620, 1050), target_size=(244,244)):
    data = []
    labels = []

    for index, row in df.iterrows():
        image_id = row['id']
        species = row['species']

        # Construct the image file path based on the ID
        image_path = os.path.join(image_folder, f"{image_id}.jpg")

        # Load the image using OpenCV in grayscale mode
        #image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)


        # Resize the image to the max size with replicated padding
        height, width = image.shape
        new_height, new_width = max_size

        # Calculate padding
        pad_height = max(0, (new_height - height) // 2)
        pad_width = max(0, (new_width - width) // 2)

        # Replicate padding
        image = cv2.copyMakeBorder(image, pad_height, pad_height, pad_width, pad_width, cv2.BORDER_REPLICATE)


        # Resize the image to the target size
        new_height, new_width = target_size

        image = cv2.resize(image, (new_width, new_height))

        # Convert OpenCV image to TensorFlow tensor
        numpy_array = np.array(image)

         # Append the image and label to the lists
        data.append(numpy_array)
        labels.append(species)

    return data,labels

# Load images and labels
images,labels = load_images_and_labels(image_folder, df, max_size=(1620, 1050), target_size=(244,244))

# %%
updated_labels = np.array(labels)
updated_images= np.array(images)

# %%
print(updated_images.shape)
print(updated_labels.shape)
# Out:
# (990, 244, 244)
# (990,)

# %%
updated_images= updated_images.reshape(len(updated_images),244,244,1)
updated_labels= updated_labels.reshape(len(updated_labels),1)

# %%
print(updated_images.shape)
print(updated_labels.shape)
# Out:
# (990, 244, 244, 1)
# (990, 1)

# %%
LabelEncoder  = preprocessing.LabelEncoder()
LabelEncoder.fit(updated_labels)
num_labels = LabelEncoder.transform(updated_labels)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %% [markdown]
# ### **Try different Optimizers**

# %%
# List of batch sizes to try
batch_sizes = [16,32,64,128]

# Dictionary to store accuracy results for each batch size
accuracy_results = {}

# Assuming you have your X_train, Y_train data ready

# Iterate through each batch size
for batch_size in batch_sizes:


    network = models.Sequential()

    # First Convolutional layer with (3,3) matrix size, same padding refers to add additional columns or rows to align
    # with the filter and a maxpooling layers which takes maximum value in the (3,3) pixel value matrix.
    network.add(layers.Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(244, 244, 1)))
    network.add(layers.MaxPool2D((2,2)))  # Reduced the pool size to (2,2) to reduce aggressive downsampling
    network.add(layers.Dropout(0.25))  # Dropout layer with 25% dropout rate

    # Second convolutional layer with 64 filters
    network.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
    network.add(layers.MaxPool2D((2,2)))
    network.add(layers.Dropout(0.25))  # Dropout layer with 25% dropout rate

    # Third convolutional layer with 128 filters
    network.add(layers.Conv2D(128, (3,3), padding='same', activation='relu'))
    network.add(layers.MaxPool2D((2,2)))
    network.add(layers.Dropout(0.25))  # Dropout layer with 25% dropout rate

    # Fourth convolutional layer with 256 filters
    network.add(layers.Conv2D(256, (3,3), padding='same', activation='relu'))
    network.add(layers.MaxPool2D((2,2)))
    network.add(layers.Dropout(0.25))  # Dropout layer with 25% dropout rate

    # Flatten layer
    network.add(layers.Flatten())

    # Dense layer of 512 neurons with ReLU activation function and L2 regularization
    network.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    network.add(layers.Dropout(0.2))  # Dropout layer with 20% dropout rate

    # Final Dense Layer with number of neurons same as number of classes of classification and 'softmax' as the
    # activation function
    network.add(layers.Dense(99, activation='softmax'))


    X_train, X_test, Y_train, Y_test = train_test_split(updated_images, num_labels, test_size=0.2, random_state=5, shuffle=True)

    Y_train_one_hot = to_categorical(Y_train, num_classes = 99)

    # Compile the model with the Adam optimizer

    network.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


    # Print model summary to check the layer shapes
    print(network.summary())

     # Train the model with the current batch size
    history = network.fit(X_train, Y_train_one_hot, epochs=50, batch_size=batch_size, verbose=1)

    # Store the accuracy results for the current batch size
    accuracy_results[batch_size] = history.history['accuracy']

# Plot the accuracy results for each batch size
plt.figure(figsize=(10, 6))
for batch_size, accuracy_values in accuracy_results.items():
    plt.plot(accuracy_values, label=f'Batch Size {batch_size}')

plt.title('Accuracy Comparison for Different Batch Sizes')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 244, 244, 32)      320
#
#  max_pooling2d_36 (MaxPooli  (None, 122, 122, 32)      0
#  ng2D)
#
#  dropout_45 (Dropout)        (None, 122, 122, 32)      0
#
#  conv2d_37 (Conv2D)          (None, 122, 122, 64)      18496
#
#  max_pooling2d_37 (MaxPooli  (None, 61, 61, 64)        0
#  ng2D)
#
#  dropout_46 (Dropout)        (None, 61, 61, 64)        0
#
#  conv2d_38 (Conv2D)          (None, 61, 61, 128)       73856
#
#  max_pooling2d_38 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  dropout_47 (Dropout)        (None, 30, 30, 128)       0
#
#  conv2d_39 (Conv2D)          (None, 30, 30, 256)       295168
#
#  max_pooling2d_39 (MaxPooli  (None, 15, 15, 256)       0
#  ng2D)
#
#  dropout_48 (Dropout)        (None, 15, 15, 256)       0
#
#  flatten_9 (Flatten)         (None, 57600)             0
#
#  dense_18 (Dense)            (None, 512)               29491712
#
#  dropout_49 (Dropout)        (None, 512)               0
#
#  dense_19 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 50/50 [==============================] - 5s 60ms/step - loss: 26.0437 - accuracy: 0.0518
# Epoch 2/50
# 50/50 [==============================] - 3s 56ms/step - loss: 8.7612 - accuracy: 0.2449
# Epoch 3/50
# 50/50 [==============================] - 3s 57ms/step - loss: 6.9768 - accuracy: 0.4217
# Epoch 4/50
# 50/50 [==============================] - 3s 58ms/step - loss: 5.9617 - accuracy: 0.5038
# Epoch 5/50
# 50/50 [==============================] - 3s 57ms/step - loss: 5.2520 - accuracy: 0.5871
# Epoch 6/50
# 50/50 [==============================] - 3s 56ms/step - loss: 4.6593 - accuracy: 0.6212
# Epoch 7/50
# 50/50 [==============================] - 3s 56ms/step - loss: 4.1841 - accuracy: 0.6616
# Epoch 8/50
# 50/50 [==============================] - 3s 58ms/step - loss: 3.8410 - accuracy: 0.6717
# Epoch 9/50
# 50/50 [==============================] - 3s 57ms/step - loss: 3.5379 - accuracy: 0.7045
# Epoch 10/50
# 50/50 [==============================] - 3s 56ms/step - loss: 3.2683 - accuracy: 0.7386
# Epoch 11/50
# 50/50 [==============================] - 3s 56ms/step - loss: 3.0287 - accuracy: 0.7386
# Epoch 12/50
# 50/50 [==============================] - 3s 57ms/step - loss: 2.8092 - accuracy: 0.7702
# Epoch 13/50
# 50/50 [==============================] - 3s 58ms/step - loss: 2.6007 - accuracy: 0.7828
# Epoch 14/50
# 50/50 [==============================] - 3s 57ms/step - loss: 2.4765 - accuracy: 0.7904
# Epoch 15/50
# 50/50 [==============================] - 3s 60ms/step - loss: 2.3119 - accuracy: 0.8232
# Epoch 16/50
# 50/50 [==============================] - 3s 57ms/step - loss: 2.1957 - accuracy: 0.8131
# Epoch 17/50
# 50/50 [==============================] - 3s 58ms/step - loss: 2.0300 - accuracy: 0.8396
# Epoch 18/50
# 50/50 [==============================] - 3s 57ms/step - loss: 2.0375 - accuracy: 0.8359
# Epoch 19/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.9561 - accuracy: 0.8422
# Epoch 20/50
# 50/50 [==============================] - 3s 58ms/step - loss: 1.8933 - accuracy: 0.8712
# Epoch 21/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.9005 - accuracy: 0.8434
# Epoch 22/50
# 50/50 [==============================] - 3s 58ms/step - loss: 1.8877 - accuracy: 0.8460
# Epoch 23/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.7923 - accuracy: 0.8447
# Epoch 24/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.6836 - accuracy: 0.8573
# Epoch 25/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.5254 - accuracy: 0.8813
# Epoch 26/50
# 50/50 [==============================] - 3s 58ms/step - loss: 1.5438 - accuracy: 0.8826
# Epoch 27/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.4784 - accuracy: 0.8851
# Epoch 28/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.5993 - accuracy: 0.8371
# Epoch 29/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.5546 - accuracy: 0.8636
# Epoch 30/50
# 50/50 [==============================] - 3s 58ms/step - loss: 1.4079 - accuracy: 0.8813
# Epoch 31/50
# 50/50 [==============================] - 3s 58ms/step - loss: 1.3362 - accuracy: 0.8939
# Epoch 32/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.4032 - accuracy: 0.8750
# Epoch 33/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.4055 - accuracy: 0.8763
# Epoch 34/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.2682 - accuracy: 0.9091
# Epoch 35/50
# 50/50 [==============================] - 3s 59ms/step - loss: 1.2360 - accuracy: 0.9003
# Epoch 36/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.2593 - accuracy: 0.8965
# Epoch 37/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.2316 - accuracy: 0.9129
# Epoch 38/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.1072 - accuracy: 0.9217
# Epoch 39/50
# 50/50 [==============================] - 3s 58ms/step - loss: 1.1238 - accuracy: 0.9078
# Epoch 40/50
# 50/50 [==============================] - 3s 58ms/step - loss: 1.1453 - accuracy: 0.9028
# Epoch 41/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.1631 - accuracy: 0.9053
# Epoch 42/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.1778 - accuracy: 0.9104
# Epoch 43/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.1206 - accuracy: 0.9343
# Epoch 44/50
# 50/50 [==============================] - 3s 59ms/step - loss: 1.3036 - accuracy: 0.8851
# Epoch 45/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.1710 - accuracy: 0.9141
# Epoch 46/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.0629 - accuracy: 0.9205
# Epoch 47/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.0561 - accuracy: 0.9141
# Epoch 48/50
# 50/50 [==============================] - 3s 58ms/step - loss: 1.0319 - accuracy: 0.9205
# Epoch 49/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.1728 - accuracy: 0.9091
# Epoch 50/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.1408 - accuracy: 0.9230
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 244, 244, 32)      320
#
#  max_pooling2d_40 (MaxPooli  (None, 122, 122, 32)      0
#  ng2D)
#
#  dropout_50 (Dropout)        (None, 122, 122, 32)      0
#
#  conv2d_41 (Conv2D)          (None, 122, 122, 64)      18496
#
#  max_pooling2d_41 (MaxPooli  (None, 61, 61, 64)        0
#  ng2D)
#
#  dropout_51 (Dropout)        (None, 61, 61, 64)        0
#
#  conv2d_42 (Conv2D)          (None, 61, 61, 128)       73856
#
#  max_pooling2d_42 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  dropout_52 (Dropout)        (None, 30, 30, 128)       0
#
#  conv2d_43 (Conv2D)          (None, 30, 30, 256)       295168
#
#  max_pooling2d_43 (MaxPooli  (None, 15, 15, 256)       0
#  ng2D)
#
#  dropout_53 (Dropout)        (None, 15, 15, 256)       0
#
#  flatten_10 (Flatten)        (None, 57600)             0
#
#  dense_20 (Dense)            (None, 512)               29491712
#
#  dropout_54 (Dropout)        (None, 512)               0
#
#  dense_21 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 25/25 [==============================] - 9s 185ms/step - loss: 23.5279 - accuracy: 0.0442
# Epoch 2/50
# 25/25 [==============================] - 2s 99ms/step - loss: 9.9169 - accuracy: 0.1705
# Epoch 3/50
# 25/25 [==============================] - 2s 99ms/step - loss: 7.8380 - accuracy: 0.3712
# Epoch 4/50
# 25/25 [==============================] - 2s 99ms/step - loss: 6.6413 - accuracy: 0.4975
# Epoch 5/50
# 25/25 [==============================] - 2s 100ms/step - loss: 5.7974 - accuracy: 0.5669
# Epoch 6/50
# 25/25 [==============================] - 3s 100ms/step - loss: 5.0483 - accuracy: 0.6553
# Epoch 7/50
# 25/25 [==============================] - 2s 99ms/step - loss: 4.5060 - accuracy: 0.6995
# Epoch 8/50
# 25/25 [==============================] - 2s 99ms/step - loss: 4.0727 - accuracy: 0.7487
# Epoch 9/50
# 25/25 [==============================] - 2s 99ms/step - loss: 3.7398 - accuracy: 0.7626
# Epoch 10/50
# 25/25 [==============================] - 3s 100ms/step - loss: 3.4835 - accuracy: 0.7462
# Epoch 11/50
# 25/25 [==============================] - 3s 101ms/step - loss: 3.1647 - accuracy: 0.7955
# Epoch 12/50
# 25/25 [==============================] - 2s 99ms/step - loss: 2.9969 - accuracy: 0.7955
# Epoch 13/50
# 25/25 [==============================] - 2s 99ms/step - loss: 2.7884 - accuracy: 0.8346
# Epoch 14/50
# 25/25 [==============================] - 2s 99ms/step - loss: 2.7250 - accuracy: 0.8131
# Epoch 15/50
# 25/25 [==============================] - 3s 100ms/step - loss: 2.4358 - accuracy: 0.8447
# Epoch 16/50
# 25/25 [==============================] - 3s 101ms/step - loss: 2.2803 - accuracy: 0.8548
# Epoch 17/50
# 25/25 [==============================] - 2s 99ms/step - loss: 2.1203 - accuracy: 0.8649
# Epoch 18/50
# 25/25 [==============================] - 2s 100ms/step - loss: 1.9550 - accuracy: 0.8902
# Epoch 19/50
# 25/25 [==============================] - 2s 100ms/step - loss: 1.9167 - accuracy: 0.8864
# Epoch 20/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.8322 - accuracy: 0.8939
# Epoch 21/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.6794 - accuracy: 0.9053
# Epoch 22/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.7406 - accuracy: 0.8763
# Epoch 23/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.6129 - accuracy: 0.8965
# Epoch 24/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.6941 - accuracy: 0.8813
# Epoch 25/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.6459 - accuracy: 0.9066
# Epoch 26/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.6162 - accuracy: 0.9104
# Epoch 27/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.6009 - accuracy: 0.9040
# Epoch 28/50
# 25/25 [==============================] - 3s 100ms/step - loss: 1.4621 - accuracy: 0.9255
# Epoch 29/50
# 25/25 [==============================] - 3s 100ms/step - loss: 1.3918 - accuracy: 0.9242
# Epoch 30/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.3326 - accuracy: 0.9280
# Epoch 31/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.2672 - accuracy: 0.9268
# Epoch 32/50
# 25/25 [==============================] - 3s 100ms/step - loss: 1.2088 - accuracy: 0.9242
# Epoch 33/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.1832 - accuracy: 0.9255
# Epoch 34/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.1810 - accuracy: 0.9293
# Epoch 35/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.1859 - accuracy: 0.9318
# Epoch 36/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.1724 - accuracy: 0.9331
# Epoch 37/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.1029 - accuracy: 0.9268
# Epoch 38/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.0622 - accuracy: 0.9394
# Epoch 39/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.0775 - accuracy: 0.9343
# Epoch 40/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.1459 - accuracy: 0.9318
# Epoch 41/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.2517 - accuracy: 0.9306
# Epoch 42/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.1946 - accuracy: 0.9470
# Epoch 43/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.1225 - accuracy: 0.9444
# Epoch 44/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.0416 - accuracy: 0.9533
# Epoch 45/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_48 (Conv2D)          (None, 244, 244, 32)      320
#
#  max_pooling2d_48 (MaxPooli  (None, 122, 122, 32)      0
#  ng2D)
#
#  dropout_60 (Dropout)        (None, 122, 122, 32)      0
#
#  conv2d_49 (Conv2D)          (None, 122, 122, 64)      18496
#
#  max_pooling2d_49 (MaxPooli  (None, 61, 61, 64)        0
#  ng2D)
#
#  dropout_61 (Dropout)        (None, 61, 61, 64)        0
#
#  conv2d_50 (Conv2D)          (None, 61, 61, 128)       73856
#
#  max_pooling2d_50 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  dropout_62 (Dropout)        (None, 30, 30, 128)       0
#
#  conv2d_51 (Conv2D)          (None, 30, 30, 256)       295168
#
#  max_pooling2d_51 (MaxPooli  (None, 15, 15, 256)       0
#  ng2D)
#
#  dropout_63 (Dropout)        (None, 15, 15, 256)       0
#
#  flatten_12 (Flatten)        (None, 57600)             0
#
#  dense_24 (Dense)            (None, 512)               29491712
#
#  dropout_64 (Dropout)        (None, 512)               0
#
#  dense_25 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 7/7 [==============================] - 13s 323ms/step - loss: 102.8775 - accuracy: 0.0202
# Epoch 2/50
# 7/7 [==============================] - 2s 319ms/step - loss: 12.2568 - accuracy: 0.0379
# Epoch 3/50
# 7/7 [==============================] - 2s 320ms/step - loss: 12.9003 - accuracy: 0.1010
# Epoch 4/50
# 7/7 [==============================] - 2s 318ms/step - loss: 12.4834 - accuracy: 0.1061
# Epoch 5/50
# 7/7 [==============================] - 2s 324ms/step - loss: 11.4372 - accuracy: 0.1894
# Epoch 6/50
# 7/7 [==============================] - 2s 319ms/step - loss: 10.4273 - accuracy: 0.3068
# Epoch 7/50
# 7/7 [==============================] - 2s 320ms/step - loss: 9.5293 - accuracy: 0.4078
# Epoch 8/50
# 7/7 [==============================] - 2s 319ms/step - loss: 8.9289 - accuracy: 0.4318
# Epoch 9/50
# 7/7 [==============================] - 2s 319ms/step - loss: 8.4138 - accuracy: 0.4785
# Epoch 10/50
# 7/7 [==============================] - 2s 322ms/step - loss: 7.9222 - accuracy: 0.5202
# Epoch 11/50
# 7/7 [==============================] - 2s 324ms/step - loss: 7.5237 - accuracy: 0.5682
# Epoch 12/50
# 7/7 [==============================] - 2s 319ms/step - loss: 7.1126 - accuracy: 0.6124
# Epoch 13/50
# 7/7 [==============================] - 2s 320ms/step - loss: 6.8793 - accuracy: 0.6098
# Epoch 14/50
# 7/7 [==============================] - 2s 320ms/step - loss: 6.5723 - accuracy: 0.6225
# Epoch 15/50
# 7/7 [==============================] - 2s 320ms/step - loss: 6.2864 - accuracy: 0.6578
# Epoch 16/50
# 7/7 [==============================] - 2s 321ms/step - loss: 6.0699 - accuracy: 0.6591
# Epoch 17/50
# 7/7 [==============================] - 2s 321ms/step - loss: 5.8287 - accuracy: 0.6742
# Epoch 18/50
# 7/7 [==============================] - 2s 318ms/step - loss: 5.6849 - accuracy: 0.6717
# Epoch 19/50
# 7/7 [==============================] - 2s 320ms/step - loss: 5.4574 - accuracy: 0.7020
# Epoch 20/50
# 7/7 [==============================] - 2s 320ms/step - loss: 5.1720 - accuracy: 0.7386
# Epoch 21/50
# 7/7 [==============================] - 2s 320ms/step - loss: 5.0943 - accuracy: 0.7273
# Epoch 22/50
# 7/7 [==============================] - 2s 320ms/step - loss: 4.9207 - accuracy: 0.7525
# Epoch 23/50
# 7/7 [==============================] - 2s 319ms/step - loss: 4.8133 - accuracy: 0.7260
# Epoch 24/50
# 7/7 [==============================] - 2s 318ms/step - loss: 4.5808 - accuracy: 0.7778
# Epoch 25/50
# 7/7 [==============================] - 2s 318ms/step - loss: 4.4944 - accuracy: 0.7803
# Epoch 26/50
# 7/7 [==============================] - 2s 317ms/step - loss: 4.3528 - accuracy: 0.7841
# Epoch 27/50
# 7/7 [==============================] - 2s 318ms/step - loss: 4.2630 - accuracy: 0.7778
# Epoch 28/50
# 7/7 [==============================] - 2s 319ms/step - loss: 4.1327 - accuracy: 0.8005
# Epoch 29/50
# 7/7 [==============================] - 2s 317ms/step - loss: 3.9773 - accuracy: 0.8093
# Epoch 30/50
# 7/7 [==============================] - 2s 317ms/step - loss: 3.8562 - accuracy: 0.8232
# Epoch 31/50
# 7/7 [==============================] - 2s 318ms/step - loss: 3.7794 - accuracy: 0.8245
# Epoch 32/50
# 7/7 [==============================] - 2s 317ms/step - loss: 3.7077 - accuracy: 0.8333
# Epoch 33/50
# 7/7 [==============================] - 2s 321ms/step - loss: 3.6500 - accuracy: 0.8232
# Epoch 34/50
# 7/7 [==============================] - 2s 318ms/step - loss: 3.5409 - accuracy: 0.8447
# Epoch 35/50
# 7/7 [==============================] - 2s 318ms/step - loss: 3.5083 - accuracy: 0.8245
# Epoch 36/50
# 7/7 [==============================] - 2s 316ms/step - loss: 3.3280 - accuracy: 0.8598
# Epoch 37/50
# 7/7 [==============================] - 2s 317ms/step - loss: 3.3233 - accuracy: 0.8497
# Epoch 38/50
# 7/7 [==============================] - 2s 320ms/step - loss: 3.2240 - accuracy: 0.8586
# Epoch 39/50
# 7/7 [==============================] - 2s 321ms/step - loss: 3.1771 - accuracy: 0.8472
# Epoch 40/50
# 7/7 [==============================] - 2s 318ms/step - loss: 3.1156 - accuracy: 0.8649
# Epoch 41/50
# 7/7 [==============================] - 2s 317ms/step - loss: 3.0054 - accuracy: 0.8813
# Epoch 42/50
# 7/7 [==============================] - 2s 317ms/step - loss: 2.9736 - accuracy: 0.8737
# Epoch 43/50
# 7/7 [==============================] - 2s 318ms/step - loss: 2.9039 - accuracy: 0.8826
# Epoch 44/50
# 7/7 [==============================] - 2s 319ms/step - loss: 2.8323 - accuracy: 0.8801
# Epoch 45/50
# 7/7 [==============================] - 2s 319ms/step - loss: 2.7498 - accuracy: 0.9003
# Epoch 46/50
# 7/7 [==============================] - 2s 318ms/step - loss: 2.7309 - accuracy: 0.8902
# Epoch 47/50
# 7/7 [==============================] - 2s 318ms/step - loss: 2.6891 - accuracy: 0.8813
# Epoch 48/50
# 7/7 [==============================] - 2s 317ms/step - loss: 2.6534 - accuracy: 0.8939
# Epoch 49/50
# 7/7 [==============================] - 2s 318ms/step - loss: 2.6058 - accuracy: 0.8914
# Epoch 50/50
# 7/7 [==============================] - 2s 320ms/step - loss: 2.5833 - accuracy: 0.8927

# %%
# Plot the accuracy results for each batch size
plt.figure(figsize=(10, 6))
for batch_size, accuracy_values in accuracy_results.items():
    plt.plot(accuracy_values, label=f'Batch Size {batch_size}')

plt.title('Accuracy Comparison for Different Batch Sizes')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
