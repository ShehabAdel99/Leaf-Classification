# %% [markdown]
# # **⬇️ Import Libraries**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import cv2
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras import regularizers
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras import models,layers

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import random
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import torch
from torch import nn
import os
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
import cv2
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras import regularizers
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras import models,layers

from keras import models, layers, regularizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import CategoricalCrossentropy

# %%
# Path to the folder containing the numbered images
image_folder = '/content/drive/MyDrive/Leaf images'

# Path to the CSV file
csv_file_path = '/content/drive/MyDrive/train.csv'

# Read the CSV file
df = pd.read_csv(csv_file_path)

# Function to load and parse images
def load_images_and_labels(image_folder, df, max_size=(1620, 1050), target_size=(244,244)):
    data = []
    labels = []

    for index, row in df.iterrows():
        image_id = row['id']
        species = row['species']

        # Construct the image file path based on the ID
        image_path = os.path.join(image_folder, f"{image_id}.jpg")

        # Load the image using OpenCV in grayscale mode
        #image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)


        # Resize the image to the max size with replicated padding
        height, width = image.shape
        new_height, new_width = max_size

        # Calculate padding
        pad_height = max(0, (new_height - height) // 2)
        pad_width = max(0, (new_width - width) // 2)

        # Replicate padding
        image = cv2.copyMakeBorder(image, pad_height, pad_height, pad_width, pad_width, cv2.BORDER_REPLICATE)


        # Resize the image to the target size
        new_height, new_width = target_size

        image = cv2.resize(image, (new_width, new_height))

        # Convert OpenCV image to TensorFlow tensor
        numpy_array = np.array(image)

         # Append the image and label to the lists
        data.append(numpy_array)
        labels.append(species)

    return data,labels

# Load images and labels
images,labels = load_images_and_labels(image_folder, df, max_size=(1620, 1050), target_size=(244,244))

# %%
updated_labels = np.array(labels)
updated_images= np.array(images)

# %%
print(updated_images.shape)
print(updated_labels.shape)
# Out:
# (990, 244, 244)
# (990,)

# %%
updated_images= updated_images.reshape(len(updated_images),244,244,1)
updated_labels= updated_labels.reshape(len(updated_labels),1)

# %%
print(updated_images.shape)
print(updated_labels.shape)
# Out:
# (990, 244, 244, 1)
# (990, 1)

# %%
LabelEncoder  = preprocessing.LabelEncoder()
LabelEncoder.fit(updated_labels)
num_labels = LabelEncoder.transform(updated_labels)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %% [markdown]
# ### **Try different Optimizers**

# %%
# List of dropout values to try
dropout_values = [0.15,0.2,0.25,0.3,0.35]

# Dictionary to store accuracy results for each dropout value
accuracy_results = {}

# Assuming you have your X_train, Y_train data ready

# Iterate through each batch size
for dropout_value in dropout_values:


    network = models.Sequential()

    # First Convolutional layer with (3,3) matrix size, same padding refers to add additional columns or rows to align
    # with the filter and a maxpooling layers which takes maximum value in the (3,3) pixel value matrix.
    network.add(layers.Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(244, 244, 1)))
    network.add(layers.MaxPool2D((2,2)))  # Reduced the pool size to (2,2) to reduce aggressive downsampling
    network.add(layers.Dropout(dropout_value))  # Dropout layer with specified dropout rate

    # Second convolutional layer with 64 filters
    network.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
    network.add(layers.MaxPool2D((2,2)))
    network.add(layers.Dropout(dropout_value))  # Dropout layer with specified dropout rate

    # Third convolutional layer with 128 filters
    network.add(layers.Conv2D(128, (3,3), padding='same', activation='relu'))
    network.add(layers.MaxPool2D((2,2)))
    network.add(layers.Dropout(dropout_value))  # Dropout layer with specified dropout rate

    # Fourth convolutional layer with 256 filters
    network.add(layers.Conv2D(256, (3,3), padding='same', activation='relu'))
    network.add(layers.MaxPool2D((2,2)))
    network.add(layers.Dropout(dropout_value))  # Dropout layer with specified dropout rate

    # Flatten layer
    network.add(layers.Flatten())

    # Dense layer of 512 neurons with ReLU activation function and L2 regularization
    network.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    network.add(layers.Dropout(dropout_value))  # Dropout layer with specified dropout rate

    # Final Dense Layer with number of neurons same as number of classes of classification and 'softmax' as the
    # activation function
    network.add(layers.Dense(99, activation='softmax'))

    # Compile the model with Adam optimizer
    network.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


    X_train, X_test, Y_train, Y_test = train_test_split(updated_images, num_labels, test_size=0.2, random_state=5, shuffle=True)

    Y_train_one_hot = to_categorical(Y_train, num_classes = 99)

    # Print model summary to check the layer shapes
    print(network.summary())

    # Train the model with the current dropout value
    history = network.fit(X_train, Y_train_one_hot, epochs=50, batch_size=32, verbose=1)

    # Store the accuracy results for the current dropout value
    accuracy_results[dropout_value] = history.history['accuracy']
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_56 (Conv2D)          (None, 244, 244, 32)      320
#
#  max_pooling2d_56 (MaxPooli  (None, 122, 122, 32)      0
#  ng2D)
#
#  dropout_70 (Dropout)        (None, 122, 122, 32)      0
#
#  conv2d_57 (Conv2D)          (None, 122, 122, 64)      18496
#
#  max_pooling2d_57 (MaxPooli  (None, 61, 61, 64)        0
#  ng2D)
#
#  dropout_71 (Dropout)        (None, 61, 61, 64)        0
#
#  conv2d_58 (Conv2D)          (None, 61, 61, 128)       73856
#
#  max_pooling2d_58 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  dropout_72 (Dropout)        (None, 30, 30, 128)       0
#
#  conv2d_59 (Conv2D)          (None, 30, 30, 256)       295168
#
#  max_pooling2d_59 (MaxPooli  (None, 15, 15, 256)       0
#  ng2D)
#
#  dropout_73 (Dropout)        (None, 15, 15, 256)       0
#
#  flatten_14 (Flatten)        (None, 57600)             0
#
#  dense_28 (Dense)            (None, 512)               29491712
#
#  dropout_74 (Dropout)        (None, 512)               0
#
#  dense_29 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 25/25 [==============================] - 5s 101ms/step - loss: 23.4376 - accuracy: 0.0391
# Epoch 2/50
# 25/25 [==============================] - 2s 98ms/step - loss: 10.3892 - accuracy: 0.1995
# Epoch 3/50
# 25/25 [==============================] - 2s 98ms/step - loss: 8.0327 - accuracy: 0.4066
# Epoch 4/50
# 25/25 [==============================] - 2s 97ms/step - loss: 6.7368 - accuracy: 0.5013
# Epoch 5/50
# 25/25 [==============================] - 2s 100ms/step - loss: 5.6438 - accuracy: 0.5795
# Epoch 6/50
# 25/25 [==============================] - 3s 102ms/step - loss: 4.9231 - accuracy: 0.6553
# Epoch 7/50
# 25/25 [==============================] - 2s 98ms/step - loss: 4.2770 - accuracy: 0.7311
# Epoch 8/50
# 25/25 [==============================] - 2s 98ms/step - loss: 3.7036 - accuracy: 0.7639
# Epoch 9/50
# 25/25 [==============================] - 2s 97ms/step - loss: 3.3359 - accuracy: 0.8220
# Epoch 10/50
# 25/25 [==============================] - 2s 100ms/step - loss: 3.0914 - accuracy: 0.8131
# Epoch 11/50
# 25/25 [==============================] - 2s 98ms/step - loss: 2.7986 - accuracy: 0.8409
# Epoch 12/50
# 25/25 [==============================] - 2s 98ms/step - loss: 2.5950 - accuracy: 0.8662
# Epoch 13/50
# 25/25 [==============================] - 2s 98ms/step - loss: 2.3979 - accuracy: 0.8687
# Epoch 14/50
# 25/25 [==============================] - 2s 98ms/step - loss: 2.1776 - accuracy: 0.8939
# Epoch 15/50
# 25/25 [==============================] - 3s 100ms/step - loss: 2.0835 - accuracy: 0.9015
# Epoch 16/50
# 25/25 [==============================] - 2s 100ms/step - loss: 1.9102 - accuracy: 0.9167
# Epoch 17/50
# 25/25 [==============================] - 2s 98ms/step - loss: 1.8440 - accuracy: 0.9003
# Epoch 18/50
# 25/25 [==============================] - 2s 98ms/step - loss: 1.6921 - accuracy: 0.9331
# Epoch 19/50
# 25/25 [==============================] - 2s 98ms/step - loss: 1.5572 - accuracy: 0.9293
# Epoch 20/50
# 25/25 [==============================] - 3s 100ms/step - loss: 1.4232 - accuracy: 0.9470
# Epoch 21/50
# 25/25 [==============================] - 2s 100ms/step - loss: 1.3366 - accuracy: 0.9457
# Epoch 22/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.2962 - accuracy: 0.9381
# Epoch 23/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.2461 - accuracy: 0.9394
# Epoch 24/50
# 25/25 [==============================] - 2s 100ms/step - loss: 1.1775 - accuracy: 0.9419
# Epoch 25/50
# 25/25 [==============================] - 2s 100ms/step - loss: 1.2047 - accuracy: 0.9419
# Epoch 26/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.1332 - accuracy: 0.9609
# Epoch 27/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.0551 - accuracy: 0.9684
# Epoch 28/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.0419 - accuracy: 0.9457
# Epoch 29/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.0564 - accuracy: 0.9356
# Epoch 30/50
# 25/25 [==============================] - 3s 100ms/step - loss: 1.0580 - accuracy: 0.9306
# Epoch 31/50
# 25/25 [==============================] - 3s 100ms/step - loss: 0.9997 - accuracy: 0.9508
# Epoch 32/50
# 25/25 [==============================] - 2s 99ms/step - loss: 0.8944 - accuracy: 0.9659
# Epoch 33/50
# 25/25 [==============================] - 2s 99ms/step - loss: 0.8622 - accuracy: 0.9684
# Epoch 34/50
# 25/25 [==============================] - 2s 100ms/step - loss: 0.9628 - accuracy: 0.9356
# Epoch 35/50
# 25/25 [==============================] - 3s 100ms/step - loss: 0.9272 - accuracy: 0.9596
# Epoch 36/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.0089 - accuracy: 0.9407
# Epoch 37/50
# 25/25 [==============================] - 2s 100ms/step - loss: 1.0798 - accuracy: 0.9381
# Epoch 38/50
# 25/25 [==============================] - 3s 100ms/step - loss: 1.0177 - accuracy: 0.9432
# Epoch 39/50
# 25/25 [==============================] - 3s 100ms/step - loss: 0.9720 - accuracy: 0.9672
# Epoch 40/50
# 25/25 [==============================] - 3s 101ms/step - loss: 0.9062 - accuracy: 0.9722
# Epoch 41/50
# 25/25 [==============================] - 3s 102ms/step - loss: 0.9810 - accuracy: 0.9558
# Epoch 42/50
# 25/25 [==============================] - 2s 100ms/step - loss: 0.9025 - accuracy: 0.9646
# Epoch 43/50
# 25/25 [==============================] - 2s 100ms/step - loss: 0.7966 - accuracy: 0.9684
# Epoch 44/50
# 25/25 [==============================] - 2s 99ms/step - loss: 0.7377 - accuracy: 0.9722
# Epoch 45/50
# 25/25 [==============================] - 2s 100ms/step - loss: 0.7200 - accuracy: 0.9659
# Epoch 46/50
# 25/25 [==============================] - 3s 102ms/step - loss: 0.7329 - accuracy: 0.9634
# Epoch 47/50
# 25/25 [==============================] - 2s 99ms/step - loss: 0.6954 - accuracy: 0.9659
# Epoch 48/50
# 25/25 [==============================] - 2s 99ms/step - loss: 0.6971 - accuracy: 0.9646
# Epoch 49/50
# 25/25 [==============================] - 2s 99ms/step - loss: 0.6601 - accuracy: 0.9646
# Epoch 50/50
# 25/25 [==============================] - 2s 99ms/step - loss: 0.7256 - accuracy: 0.9407
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_60 (Conv2D)          (None, 244, 244, 32)      320
#
#  max_pooling2d_60 (MaxPooli  (None, 122, 122, 32)      0
#  ng2D)
#
#  dropout_75 (Dropout)        (None, 122, 122, 32)      0
#
#  conv2d_61 (Conv2D)          (None, 122, 122, 64)      18496
#
#  max_pooling2d_61 (MaxPooli  (None, 61, 61, 64)        0
#  ng2D)
#
#  dropout_76 (Dropout)        (None, 61, 61, 64)        0
#
#  conv2d_62 (Conv2D)          (None, 61, 61, 128)       73856
#
#  max_pooling2d_62 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  dropout_77 (Dropout)        (None, 30, 30, 128)       0
#
#  conv2d_63 (Conv2D)          (None, 30, 30, 256)       295168
#
#  max_pooling2d_63 (MaxPooli  (None, 15, 15, 256)       0
#  ng2D)
#
#  dropout_78 (Dropout)        (None, 15, 15, 256)       0
#
#  flatten_15 (Flatten)        (None, 57600)             0
#
#  dense_30 (Dense)            (None, 512)               29491712
#
#  dropout_79 (Dropout)        (None, 512)               0
#
#  dense_31 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 25/25 [==============================] - 5s 102ms/step - loss: 35.5523 - accuracy: 0.0581
# Epoch 2/50
# 25/25 [==============================] - 2s 99ms/step - loss: 10.4334 - accuracy: 0.2210
# Epoch 3/50
# 25/25 [==============================] - 2s 99ms/step - loss: 8.5707 - accuracy: 0.4394
# Epoch 4/50
# 25/25 [==============================] - 2s 99ms/step - loss: 7.3663 - accuracy: 0.5467
# Epoch 5/50
# 25/25 [==============================] - 3s 103ms/step - loss: 6.4935 - accuracy: 0.6490
# Epoch 6/50
# 25/25 [==============================] - 2s 100ms/step - loss: 5.7716 - accuracy: 0.6944
# Epoch 7/50
# 25/25 [==============================] - 2s 99ms/step - loss: 5.2546 - accuracy: 0.7121
# Epoch 8/50
# 25/25 [==============================] - 2s 99ms/step - loss: 4.8482 - accuracy: 0.7475
# Epoch 9/50
# 25/25 [==============================] - 2s 100ms/step - loss: 4.4790 - accuracy: 0.7664
# Epoch 10/50
# 25/25 [==============================] - 3s 102ms/step - loss: 4.0624 - accuracy: 0.8093
# Epoch 11/50
# 25/25 [==============================] - 3s 100ms/step - loss: 3.7827 - accuracy: 0.8194
# Epoch 12/50
# 25/25 [==============================] - 2s 100ms/step - loss: 3.5428 - accuracy: 0.8396
# Epoch 13/50
# 25/25 [==============================] - 3s 100ms/step - loss: 3.3206 - accuracy: 0.8523
# Epoch 14/50
# 25/25 [==============================] - 3s 100ms/step - loss: 3.0912 - accuracy: 0.8801
# Epoch 15/50
# 25/25 [==============================] - 3s 103ms/step - loss: 2.9428 - accuracy: 0.8838
# Epoch 16/50
# 25/25 [==============================] - 3s 102ms/step - loss: 3.0004 - accuracy: 0.8497
# Epoch 17/50
# 25/25 [==============================] - 3s 102ms/step - loss: 2.7689 - accuracy: 0.8699
# Epoch 18/50
# 25/25 [==============================] - 3s 101ms/step - loss: 2.6523 - accuracy: 0.8939
# Epoch 19/50
# 25/25 [==============================] - 3s 101ms/step - loss: 2.5080 - accuracy: 0.8977
# Epoch 20/50
# 25/25 [==============================] - 3s 104ms/step - loss: 2.3211 - accuracy: 0.9205
# Epoch 21/50
# 25/25 [==============================] - 3s 102ms/step - loss: 2.1711 - accuracy: 0.9129
# Epoch 22/50
# 25/25 [==============================] - 3s 101ms/step - loss: 2.1221 - accuracy: 0.9028
# Epoch 23/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.9836 - accuracy: 0.9293
# Epoch 24/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.8692 - accuracy: 0.9331
# Epoch 25/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.7969 - accuracy: 0.9280
# Epoch 26/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.6976 - accuracy: 0.9356
# Epoch 27/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.6281 - accuracy: 0.9444
# Epoch 28/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.6167 - accuracy: 0.9381
# Epoch 29/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.5855 - accuracy: 0.9394
# Epoch 30/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.5278 - accuracy: 0.9318
# Epoch 31/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.4587 - accuracy: 0.9457
# Epoch 32/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.5461 - accuracy: 0.9205
# Epoch 33/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.4808 - accuracy: 0.9066
# Epoch 34/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.5656 - accuracy: 0.9003
# Epoch 35/50
# 25/25 [==============================] - 3s 105ms/step - loss: 1.4338 - accuracy: 0.9394
# Epoch 36/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.4399 - accuracy: 0.9280
# Epoch 37/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.3436 - accuracy: 0.9533
# Epoch 38/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.3218 - accuracy: 0.9571
# Epoch 39/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.3792 - accuracy: 0.9444
# Epoch 40/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.3753 - accuracy: 0.9457
# Epoch 41/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.3386 - accuracy: 0.9470
# Epoch 42/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.2771 - accuracy: 0.9407
# Epoch 43/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.2122 - accuracy: 0.9508
# Epoch 44/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.1958 - accuracy: 0.9495
# Epoch 45/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.1243 - accuracy: 0.9558
# Epoch 46/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.1253 - accuracy: 0.9482
# Epoch 47/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.1570 - accuracy: 0.9369
# Epoch 48/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.0937 - accuracy: 0.9583
# Epoch 49/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.1036 - accuracy: 0.9495
# Epoch 50/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.0442 - accuracy: 0.9558
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_64 (Conv2D)          (None, 244, 244, 32)      320
#
#  max_pooling2d_64 (MaxPooli  (None, 122, 122, 32)      0
#  ng2D)
#
#  dropout_80 (Dropout)        (None, 122, 122, 32)      0
#
#  conv2d_65 (Conv2D)          (None, 122, 122, 64)      18496
#
#  max_pooling2d_65 (MaxPooli  (None, 61, 61, 64)        0
#  ng2D)
#
#  dropout_81 (Dropout)        (None, 61, 61, 64)        0
#
#  conv2d_66 (Conv2D)          (None, 61, 61, 128)       73856
#
#  max_pooling2d_66 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  dropout_82 (Dropout)        (None, 30, 30, 128)       0
#
#  conv2d_67 (Conv2D)          (None, 30, 30, 256)       295168
#
#  max_pooling2d_67 (MaxPooli  (None, 15, 15, 256)       0
#  ng2D)
#
#  dropout_83 (Dropout)        (None, 15, 15, 256)       0
#
#  flatten_16 (Flatten)        (None, 57600)             0
#
#  dense_32 (Dense)            (None, 512)               29491712
#
#  dropout_84 (Dropout)        (None, 512)               0
#
#  dense_33 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 25/25 [==============================] - 4s 101ms/step - loss: 32.9262 - accuracy: 0.0417
# Epoch 2/50
# 25/25 [==============================] - 2s 99ms/step - loss: 10.9223 - accuracy: 0.1604
# Epoch 3/50
# 25/25 [==============================] - 2s 100ms/step - loss: 9.0301 - accuracy: 0.3308
# Epoch 4/50
# 25/25 [==============================] - 3s 101ms/step - loss: 7.9228 - accuracy: 0.4621
# Epoch 5/50
# 25/25 [==============================] - 2s 99ms/step - loss: 6.9128 - accuracy: 0.5720
# Epoch 6/50
# 25/25 [==============================] - 2s 99ms/step - loss: 6.2609 - accuracy: 0.6073
# Epoch 7/50
# 25/25 [==============================] - 2s 99ms/step - loss: 5.7734 - accuracy: 0.6566
# Epoch 8/50
# 25/25 [==============================] - 2s 100ms/step - loss: 5.1942 - accuracy: 0.7008
# Epoch 9/50
# 25/25 [==============================] - 3s 102ms/step - loss: 4.8799 - accuracy: 0.6995
# Epoch 10/50
# 25/25 [==============================] - 2s 99ms/step - loss: 4.5382 - accuracy: 0.7462
# Epoch 11/50
# 25/25 [==============================] - 2s 99ms/step - loss: 4.2250 - accuracy: 0.7765
# Epoch 12/50
# 25/25 [==============================] - 2s 100ms/step - loss: 3.9595 - accuracy: 0.7879
# Epoch 13/50
# 25/25 [==============================] - 3s 100ms/step - loss: 3.6730 - accuracy: 0.8119
# Epoch 14/50
# 25/25 [==============================] - 3s 102ms/step - loss: 3.3654 - accuracy: 0.8333
# Epoch 15/50
# 25/25 [==============================] - 2s 99ms/step - loss: 3.2261 - accuracy: 0.8157
# Epoch 16/50
# 25/25 [==============================] - 2s 99ms/step - loss: 3.0281 - accuracy: 0.8447
# Epoch 17/50
# 25/25 [==============================] - 2s 99ms/step - loss: 2.9312 - accuracy: 0.8409
# Epoch 18/50
# 25/25 [==============================] - 2s 100ms/step - loss: 2.7986 - accuracy: 0.8523
# Epoch 19/50
# 25/25 [==============================] - 3s 102ms/step - loss: 2.7619 - accuracy: 0.8699
# Epoch 20/50
# 25/25 [==============================] - 2s 99ms/step - loss: 2.6406 - accuracy: 0.8763
# Epoch 21/50
# 25/25 [==============================] - 2s 99ms/step - loss: 2.4872 - accuracy: 0.8914
# Epoch 22/50
# 25/25 [==============================] - 2s 99ms/step - loss: 2.3694 - accuracy: 0.8876
# Epoch 23/50
# 25/25 [==============================] - 2s 99ms/step - loss: 2.2373 - accuracy: 0.9028
# Epoch 24/50
# 25/25 [==============================] - 3s 102ms/step - loss: 2.1370 - accuracy: 0.9091
# Epoch 25/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.9760 - accuracy: 0.9192
# Epoch 26/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.8887 - accuracy: 0.9230
# Epoch 27/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.8229 - accuracy: 0.9154
# Epoch 28/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.8282 - accuracy: 0.9003
# Epoch 29/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.8067 - accuracy: 0.8990
# Epoch 30/50
# 25/25 [==============================] - 2s 100ms/step - loss: 1.7179 - accuracy: 0.8990
# Epoch 31/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.6115 - accuracy: 0.9242
# Epoch 32/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.6876 - accuracy: 0.9179
# Epoch 33/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.7415 - accuracy: 0.8927
# Epoch 34/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.6806 - accuracy: 0.9141
# Epoch 35/50
# 25/25 [==============================] - 2s 100ms/step - loss: 1.5629 - accuracy: 0.9255
# Epoch 36/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.4538 - accuracy: 0.9444
# Epoch 37/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.4172 - accuracy: 0.9293
# Epoch 38/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.3377 - accuracy: 0.9306
# Epoch 39/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.3458 - accuracy: 0.9230
# Epoch 40/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.3610 - accuracy: 0.9104
# Epoch 41/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.2306 - accuracy: 0.9533
# Epoch 42/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.2967 - accuracy: 0.9242
# Epoch 43/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.2902 - accuracy: 0.9268
# Epoch 44/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.2650 - accuracy: 0.9242
# Epoch 45/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.2687 - accuracy: 0.9268
# Epoch 46/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.2902 - accuracy: 0.9217
# Epoch 47/50
# 25/25 [==============================] - 2s 99ms/step - loss: 1.2598 - accuracy: 0.9381
# Epoch 48/50
# 25/25 [==============================] - 2s 100ms/step - loss: 1.1534 - accuracy: 0.9508
# Epoch 49/50
# 25/25 [==============================] - 3s 100ms/step - loss: 1.1998 - accuracy: 0.9242
# Epoch 50/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.2004 - accuracy: 0.9242
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_68 (Conv2D)          (None, 244, 244, 32)      320
#
#  max_pooling2d_68 (MaxPooli  (None, 122, 122, 32)      0
#  ng2D)
#
#  dropout_85 (Dropout)        (None, 122, 122, 32)      0
#
#  conv2d_69 (Conv2D)          (None, 122, 122, 64)      18496
#
#  max_pooling2d_69 (MaxPooli  (None, 61, 61, 64)        0
#  ng2D)
#
#  dropout_86 (Dropout)        (None, 61, 61, 64)        0
#
#  conv2d_70 (Conv2D)          (None, 61, 61, 128)       73856
#
#  max_pooling2d_70 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  dropout_87 (Dropout)        (None, 30, 30, 128)       0
#
#  conv2d_71 (Conv2D)          (None, 30, 30, 256)       295168
#
#  max_pooling2d_71 (MaxPooli  (None, 15, 15, 256)       0
#  ng2D)
#
#  dropout_88 (Dropout)        (None, 15, 15, 256)       0
#
#  flatten_17 (Flatten)        (None, 57600)             0
#
#  dense_34 (Dense)            (None, 512)               29491712
#
#  dropout_89 (Dropout)        (None, 512)               0
#
#  dense_35 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 25/25 [==============================] - 4s 103ms/step - loss: 49.0712 - accuracy: 0.0316
# Epoch 2/50
# 25/25 [==============================] - 3s 100ms/step - loss: 11.3480 - accuracy: 0.1313
# Epoch 3/50
# 25/25 [==============================] - 3s 100ms/step - loss: 9.6787 - accuracy: 0.3081
# Epoch 4/50
# 25/25 [==============================] - 3s 102ms/step - loss: 8.5881 - accuracy: 0.4003
# Epoch 5/50
# 25/25 [==============================] - 2s 100ms/step - loss: 7.7847 - accuracy: 0.4646
# Epoch 6/50
# 25/25 [==============================] - 2s 100ms/step - loss: 7.2479 - accuracy: 0.5253
# Epoch 7/50
# 25/25 [==============================] - 2s 100ms/step - loss: 6.7295 - accuracy: 0.5505
# Epoch 8/50
# 25/25 [==============================] - 2s 100ms/step - loss: 6.2508 - accuracy: 0.5909
# Epoch 9/50
# 25/25 [==============================] - 3s 102ms/step - loss: 5.8358 - accuracy: 0.6364
# Epoch 10/50
# 25/25 [==============================] - 2s 99ms/step - loss: 5.4846 - accuracy: 0.6528
# Epoch 11/50
# 25/25 [==============================] - 2s 98ms/step - loss: 5.1553 - accuracy: 0.6806
# Epoch 12/50
# 25/25 [==============================] - 2s 98ms/step - loss: 4.9962 - accuracy: 0.6553
# Epoch 13/50
# 25/25 [==============================] - 2s 99ms/step - loss: 4.6469 - accuracy: 0.7159
# Epoch 14/50
# 25/25 [==============================] - 3s 101ms/step - loss: 4.4307 - accuracy: 0.7285
# Epoch 15/50
# 25/25 [==============================] - 2s 99ms/step - loss: 4.2520 - accuracy: 0.7412
# Epoch 16/50
# 25/25 [==============================] - 2s 99ms/step - loss: 4.0510 - accuracy: 0.7462
# Epoch 17/50
# 25/25 [==============================] - 2s 99ms/step - loss: 3.8996 - accuracy: 0.7525
# Epoch 18/50
# 25/25 [==============================] - 2s 99ms/step - loss: 3.6933 - accuracy: 0.7626
# Epoch 19/50
# 25/25 [==============================] - 3s 101ms/step - loss: 3.5014 - accuracy: 0.7879
# Epoch 20/50
# 25/25 [==============================] - 2s 99ms/step - loss: 3.3703 - accuracy: 0.8119
# Epoch 21/50
# 25/25 [==============================] - 2s 99ms/step - loss: 3.2705 - accuracy: 0.8093
# Epoch 22/50
# 25/25 [==============================] - 2s 99ms/step - loss: 3.1578 - accuracy: 0.8144
# Epoch 23/50
# 25/25 [==============================] - 2s 99ms/step - loss: 3.0025 - accuracy: 0.8270
# Epoch 24/50
# 25/25 [==============================] - 3s 102ms/step - loss: 3.0158 - accuracy: 0.8245
# Epoch 25/50
# 25/25 [==============================] - 3s 101ms/step - loss: 2.8312 - accuracy: 0.8447
# Epoch 26/50
# 25/25 [==============================] - 3s 100ms/step - loss: 2.8002 - accuracy: 0.8308
# Epoch 27/50
# 25/25 [==============================] - 3s 101ms/step - loss: 2.6724 - accuracy: 0.8409
# Epoch 28/50
# 25/25 [==============================] - 3s 102ms/step - loss: 2.5882 - accuracy: 0.8384
# Epoch 29/50
# 25/25 [==============================] - 3s 103ms/step - loss: 2.4126 - accuracy: 0.8813
# Epoch 30/50
# 25/25 [==============================] - 3s 102ms/step - loss: 2.3187 - accuracy: 0.8775
# Epoch 31/50
# 25/25 [==============================] - 3s 101ms/step - loss: 2.3810 - accuracy: 0.8510
# Epoch 32/50
# 25/25 [==============================] - 3s 101ms/step - loss: 2.3400 - accuracy: 0.8649
# Epoch 33/50
# 25/25 [==============================] - 3s 101ms/step - loss: 2.2246 - accuracy: 0.8775
# Epoch 34/50
# 25/25 [==============================] - 3s 103ms/step - loss: 2.1807 - accuracy: 0.8750
# Epoch 35/50
# 25/25 [==============================] - 3s 103ms/step - loss: 2.2089 - accuracy: 0.8485
# Epoch 36/50
# 25/25 [==============================] - 3s 101ms/step - loss: 2.0929 - accuracy: 0.8838
# Epoch 37/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.9914 - accuracy: 0.9003
# Epoch 38/50
# 25/25 [==============================] - 3s 102ms/step - loss: 2.0691 - accuracy: 0.8662
# Epoch 39/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.9457 - accuracy: 0.8838
# Epoch 40/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.8479 - accuracy: 0.8990
# Epoch 41/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.8248 - accuracy: 0.9028
# Epoch 42/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.7930 - accuracy: 0.9028
# Epoch 43/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.7187 - accuracy: 0.9154
# Epoch 44/50
# 25/25 [==============================] - 3s 104ms/step - loss: 1.8017 - accuracy: 0.8876
# Epoch 45/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.7279 - accuracy: 0.8902
# Epoch 46/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.6743 - accuracy: 0.9129
# Epoch 47/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.7593 - accuracy: 0.8801
# Epoch 48/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.6552 - accuracy: 0.8952
# Epoch 49/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.5462 - accuracy: 0.9255
# Epoch 50/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.6203 - accuracy: 0.8876
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_72 (Conv2D)          (None, 244, 244, 32)      320
#
#  max_pooling2d_72 (MaxPooli  (None, 122, 122, 32)      0
#  ng2D)
#
#  dropout_90 (Dropout)        (None, 122, 122, 32)      0
#
#  conv2d_73 (Conv2D)          (None, 122, 122, 64)      18496
#
#  max_pooling2d_73 (MaxPooli  (None, 61, 61, 64)        0
#  ng2D)
#
#  dropout_91 (Dropout)        (None, 61, 61, 64)        0
#
#  conv2d_74 (Conv2D)          (None, 61, 61, 128)       73856
#
#  max_pooling2d_74 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  dropout_92 (Dropout)        (None, 30, 30, 128)       0
#
#  conv2d_75 (Conv2D)          (None, 30, 30, 256)       295168
#
#  max_pooling2d_75 (MaxPooli  (None, 15, 15, 256)       0
#  ng2D)
#
#  dropout_93 (Dropout)        (None, 15, 15, 256)       0
#
#  flatten_18 (Flatten)        (None, 57600)             0
#
#  dense_36 (Dense)            (None, 512)               29491712
#
#  dropout_94 (Dropout)        (None, 512)               0
#
#  dense_37 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 25/25 [==============================] - 4s 102ms/step - loss: 56.6274 - accuracy: 0.0202
# Epoch 2/50
# 25/25 [==============================] - 3s 100ms/step - loss: 11.8924 - accuracy: 0.0694
# Epoch 3/50
# 25/25 [==============================] - 3s 101ms/step - loss: 10.3790 - accuracy: 0.2159
# Epoch 4/50
# 25/25 [==============================] - 3s 102ms/step - loss: 9.2012 - accuracy: 0.3220
# Epoch 5/50
# 25/25 [==============================] - 2s 100ms/step - loss: 8.3006 - accuracy: 0.4255
# Epoch 6/50
# 25/25 [==============================] - 2s 100ms/step - loss: 7.7879 - accuracy: 0.4457
# Epoch 7/50
# 25/25 [==============================] - 2s 99ms/step - loss: 7.2275 - accuracy: 0.5227
# Epoch 8/50
# 25/25 [==============================] - 2s 100ms/step - loss: 6.8142 - accuracy: 0.5530
# Epoch 9/50
# 25/25 [==============================] - 3s 101ms/step - loss: 6.3821 - accuracy: 0.5859
# Epoch 10/50
# 25/25 [==============================] - 2s 99ms/step - loss: 6.0531 - accuracy: 0.6023
# Epoch 11/50
# 25/25 [==============================] - 2s 99ms/step - loss: 5.6831 - accuracy: 0.6439
# Epoch 12/50
# 25/25 [==============================] - 2s 99ms/step - loss: 5.4380 - accuracy: 0.6503
# Epoch 13/50
# 25/25 [==============================] - 2s 99ms/step - loss: 5.1883 - accuracy: 0.6730
# Epoch 14/50
# 25/25 [==============================] - 3s 102ms/step - loss: 4.9776 - accuracy: 0.6831
# Epoch 15/50
# 25/25 [==============================] - 2s 99ms/step - loss: 4.8152 - accuracy: 0.6780
# Epoch 16/50
# 25/25 [==============================] - 2s 99ms/step - loss: 4.6393 - accuracy: 0.6982
# Epoch 17/50
# 25/25 [==============================] - 2s 100ms/step - loss: 4.4095 - accuracy: 0.7172
# Epoch 18/50
# 25/25 [==============================] - 2s 100ms/step - loss: 4.2121 - accuracy: 0.7374
# Epoch 19/50
# 25/25 [==============================] - 3s 101ms/step - loss: 4.0744 - accuracy: 0.7311
# Epoch 20/50
# 25/25 [==============================] - 2s 99ms/step - loss: 3.9602 - accuracy: 0.7260
# Epoch 21/50
# 25/25 [==============================] - 2s 99ms/step - loss: 3.7810 - accuracy: 0.7475
# Epoch 22/50
# 25/25 [==============================] - 2s 100ms/step - loss: 3.6575 - accuracy: 0.7753
# Epoch 23/50
# 25/25 [==============================] - 2s 99ms/step - loss: 3.5544 - accuracy: 0.7753
# Epoch 24/50
# 25/25 [==============================] - 3s 102ms/step - loss: 3.4352 - accuracy: 0.7790
# Epoch 25/50
# 25/25 [==============================] - 3s 100ms/step - loss: 3.3172 - accuracy: 0.7727
# Epoch 26/50
# 25/25 [==============================] - 2s 99ms/step - loss: 3.2139 - accuracy: 0.7917
# Epoch 27/50
# 25/25 [==============================] - 2s 99ms/step - loss: 3.1414 - accuracy: 0.7917
# Epoch 28/50
# 25/25 [==============================] - 2s 99ms/step - loss: 3.1216 - accuracy: 0.7828
# Epoch 29/50
# 25/25 [==============================] - 3s 101ms/step - loss: 2.9645 - accuracy: 0.8182
# Epoch 30/50
# 25/25 [==============================] - 3s 101ms/step - loss: 2.8378 - accuracy: 0.8194
# Epoch 31/50
# 25/25 [==============================] - 2s 100ms/step - loss: 2.7820 - accuracy: 0.8030
# Epoch 32/50
# 25/25 [==============================] - 2s 99ms/step - loss: 2.7844 - accuracy: 0.8056
# Epoch 33/50
# 25/25 [==============================] - 2s 100ms/step - loss: 2.7882 - accuracy: 0.7891
# Epoch 34/50
# 25/25 [==============================] - 3s 103ms/step - loss: 2.7296 - accuracy: 0.8194
# Epoch 35/50
# 25/25 [==============================] - 3s 101ms/step - loss: 2.6089 - accuracy: 0.8169
# Epoch 36/50
# 25/25 [==============================] - 2s 100ms/step - loss: 2.4907 - accuracy: 0.8371
# Epoch 37/50
# 25/25 [==============================] - 2s 100ms/step - loss: 2.4201 - accuracy: 0.8434
# Epoch 38/50
# 25/25 [==============================] - 2s 100ms/step - loss: 2.3412 - accuracy: 0.8434
# Epoch 39/50
# 25/25 [==============================] - 3s 102ms/step - loss: 2.2904 - accuracy: 0.8485
# Epoch 40/50
# 25/25 [==============================] - 3s 101ms/step - loss: 2.2530 - accuracy: 0.8801
# Epoch 41/50
# 25/25 [==============================] - 2s 100ms/step - loss: 2.2666 - accuracy: 0.8434
# Epoch 42/50
# 25/25 [==============================] - 2s 100ms/step - loss: 2.1820 - accuracy: 0.8510
# Epoch 43/50
# 25/25 [==============================] - 2s 100ms/step - loss: 2.1216 - accuracy: 0.8586
# Epoch 44/50
# 25/25 [==============================] - 3s 102ms/step - loss: 2.0767 - accuracy: 0.8561
# Epoch 45/50
# 25/25 [==============================] - 3s 102ms/step - loss: 2.0546 - accuracy: 0.8674
# Epoch 46/50
# 25/25 [==============================] - 2s 100ms/step - loss: 2.0805 - accuracy: 0.8485
# Epoch 47/50
# 25/25 [==============================] - 2s 100ms/step - loss: 2.0403 - accuracy: 0.8598
# Epoch 48/50
# 25/25 [==============================] - 2s 100ms/step - loss: 1.9934 - accuracy: 0.8725
# Epoch 49/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.9162 - accuracy: 0.8965
# Epoch 50/50
# 25/25 [==============================] - 3s 102ms/step - loss: 1.9248 - accuracy: 0.8725

# %%
# Plot the accuracy results for each dropout value
plt.figure(figsize=(10, 6))
for dropout_value, accuracy_values in accuracy_results.items():
    plt.plot(accuracy_values, label=f'Dropout {dropout_value}')

plt.title('Accuracy Comparison for Different Dropout Values')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
