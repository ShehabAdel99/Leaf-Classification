# %% [markdown]
# # **⬇️ Import Libraries**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import cv2
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras import regularizers
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras import models,layers

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import random
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import torch
from torch import nn
import os
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
import cv2
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras import regularizers
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras import models,layers

from keras import models, layers, regularizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import CategoricalCrossentropy

# %%
# Path to the folder containing the numbered images
image_folder = '/content/drive/MyDrive/Leaf images'

# Path to the CSV file
csv_file_path = '/content/drive/MyDrive/train.csv'

# Read the CSV file
df = pd.read_csv(csv_file_path)

# Function to load and parse images
def load_images_and_labels(image_folder, df, max_size=(1620, 1050), target_size=(244,244)):
    data = []
    labels = []

    for index, row in df.iterrows():
        image_id = row['id']
        species = row['species']

        # Construct the image file path based on the ID
        image_path = os.path.join(image_folder, f"{image_id}.jpg")

        # Load the image using OpenCV in grayscale mode
        #image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)


        # Resize the image to the max size with replicated padding
        height, width = image.shape
        new_height, new_width = max_size

        # Calculate padding
        pad_height = max(0, (new_height - height) // 2)
        pad_width = max(0, (new_width - width) // 2)

        # Replicate padding
        image = cv2.copyMakeBorder(image, pad_height, pad_height, pad_width, pad_width, cv2.BORDER_REPLICATE)


        # Resize the image to the target size
        new_height, new_width = target_size

        image = cv2.resize(image, (new_width, new_height))

        # Convert OpenCV image to TensorFlow tensor
        numpy_array = np.array(image)

         # Append the image and label to the lists
        data.append(numpy_array)
        labels.append(species)

    return data,labels

# Load images and labels
images,labels = load_images_and_labels(image_folder, df, max_size=(1620, 1050), target_size=(244,244))

# %%
updated_labels = np.array(labels)
updated_images= np.array(images)

# %%
print(updated_images.shape)
print(updated_labels.shape)
# Out:
# (990, 244, 244)
# (990,)

# %%
updated_images= updated_images.reshape(len(updated_images),244,244,1)
updated_labels= updated_labels.reshape(len(updated_labels),1)

# %%
print(updated_images.shape)
print(updated_labels.shape)
# Out:
# (990, 244, 244, 1)
# (990, 1)

# %%
LabelEncoder  = preprocessing.LabelEncoder()
LabelEncoder.fit(updated_labels)
num_labels = LabelEncoder.transform(updated_labels)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %% [markdown]
# ### **Try different Optimizers**

# %%
# List of optimizers to try
optimizers = ['sgd','adam', 'adagrad']

# Dictionary to store accuracy results for each optimizer
accuracy_results = {}

# Assuming you have your X_train, Y_train data ready

# Iterate through each optimizer
for optimizer_name in optimizers:


    network = models.Sequential()

    # First Convolutional layer with (3,3) matrix size, same padding refers to add additional columns or rows to align
    # with the filter and a maxpooling layers which takes maximum value in the (3,3) pixel value matrix.
    network.add(layers.Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(244, 244, 1)))
    network.add(layers.MaxPool2D((2,2)))  # Reduced the pool size to (2,2) to reduce aggressive downsampling
    network.add(layers.Dropout(0.25))  # Dropout layer with 25% dropout rate

    # Second convolutional layer with 64 filters
    network.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
    network.add(layers.MaxPool2D((2,2)))
    network.add(layers.Dropout(0.25))  # Dropout layer with 25% dropout rate

    # Third convolutional layer with 128 filters
    network.add(layers.Conv2D(128, (3,3), padding='same', activation='relu'))
    network.add(layers.MaxPool2D((2,2)))
    network.add(layers.Dropout(0.25))  # Dropout layer with 25% dropout rate

    # Fourth convolutional layer with 256 filters
    network.add(layers.Conv2D(256, (3,3), padding='same', activation='relu'))
    network.add(layers.MaxPool2D((2,2)))
    network.add(layers.Dropout(0.25))  # Dropout layer with 25% dropout rate

    # Flatten layer
    network.add(layers.Flatten())

    # Dense layer of 512 neurons with ReLU activation function and L2 regularization
    network.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    network.add(layers.Dropout(0.2))  # Dropout layer with 20% dropout rate

    # Final Dense Layer with number of neurons same as number of classes of classification and 'softmax' as the
    # activation function
    network.add(layers.Dense(99, activation='softmax'))


    X_train, X_test, Y_train, Y_test = train_test_split(updated_images, num_labels, test_size=0.2, random_state=5, shuffle=True)

    Y_train_one_hot = to_categorical(Y_train, num_classes = 99)

    # Compile the model with the current optimizer
    if optimizer_name == 'sgd':
      optimizer_sgd = SGD(learning_rate=0.001)
      network.compile(optimizer=optimizer_sgd, loss='categorical_crossentropy', metrics=['accuracy'])
    else:
      network.compile(optimizer=optimizer_name, loss='categorical_crossentropy', metrics=['accuracy'])


    # Print model summary to check the layer shapes
    print(network.summary())

    # Train the model (assuming X_train and Y_train_one_hot are defined)
    history = network.fit(X_train, Y_train_one_hot, epochs=50, batch_size=16, verbose=1)

    # Store the accuracy results for the current optimizer
    accuracy_results[optimizer_name] = history.history['accuracy']

# Plot the accuracy results for each optimizer
plt.figure(figsize=(10, 6))
for optimizer_name, accuracy_values in accuracy_results.items():
    plt.plot(accuracy_values, label=optimizer_name)

plt.title('Accuracy Comparison for Different Optimizers')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 244, 244, 32)      320
#
#  max_pooling2d_24 (MaxPooli  (None, 122, 122, 32)      0
#  ng2D)
#
#  dropout_30 (Dropout)        (None, 122, 122, 32)      0
#
#  conv2d_25 (Conv2D)          (None, 122, 122, 64)      18496
#
#  max_pooling2d_25 (MaxPooli  (None, 61, 61, 64)        0
#  ng2D)
#
#  dropout_31 (Dropout)        (None, 61, 61, 64)        0
#
#  conv2d_26 (Conv2D)          (None, 61, 61, 128)       73856
#
#  max_pooling2d_26 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  dropout_32 (Dropout)        (None, 30, 30, 128)       0
#
#  conv2d_27 (Conv2D)          (None, 30, 30, 256)       295168
#
#  max_pooling2d_27 (MaxPooli  (None, 15, 15, 256)       0
#  ng2D)
#
#  dropout_33 (Dropout)        (None, 15, 15, 256)       0
#
#  flatten_6 (Flatten)         (None, 57600)             0
#
#  dense_12 (Dense)            (None, 512)               29491712
#
#  dropout_34 (Dropout)        (None, 512)               0
#
#  dense_13 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 50/50 [==============================] - 4s 57ms/step - loss: 21.4427 - accuracy: 0.0215
# Epoch 2/50
# 50/50 [==============================] - 3s 55ms/step - loss: 14.4639 - accuracy: 0.0631
# Epoch 3/50
# 50/50 [==============================] - 3s 55ms/step - loss: 14.0232 - accuracy: 0.1301
# Epoch 4/50
# 50/50 [==============================] - 3s 55ms/step - loss: 13.5643 - accuracy: 0.1957
# Epoch 5/50
# 50/50 [==============================] - 3s 56ms/step - loss: 13.1407 - accuracy: 0.2449
# Epoch 6/50
# 50/50 [==============================] - 3s 55ms/step - loss: 12.7039 - accuracy: 0.3321
# Epoch 7/50
# 50/50 [==============================] - 3s 54ms/step - loss: 12.4013 - accuracy: 0.3737
# Epoch 8/50
# 50/50 [==============================] - 3s 54ms/step - loss: 12.2133 - accuracy: 0.4356
# Epoch 9/50
# 50/50 [==============================] - 3s 55ms/step - loss: 11.9312 - accuracy: 0.4811
# Epoch 10/50
# 50/50 [==============================] - 3s 56ms/step - loss: 11.7537 - accuracy: 0.5202
# Epoch 11/50
# 50/50 [==============================] - 3s 55ms/step - loss: 11.6161 - accuracy: 0.5278
# Epoch 12/50
# 50/50 [==============================] - 3s 54ms/step - loss: 11.4904 - accuracy: 0.5631
# Epoch 13/50
# 50/50 [==============================] - 3s 55ms/step - loss: 11.2891 - accuracy: 0.6212
# Epoch 14/50
# 50/50 [==============================] - 3s 55ms/step - loss: 11.2368 - accuracy: 0.6162
# Epoch 15/50
# 50/50 [==============================] - 3s 56ms/step - loss: 11.1136 - accuracy: 0.6503
# Epoch 16/50
# 50/50 [==============================] - 3s 55ms/step - loss: 10.9831 - accuracy: 0.6439
# Epoch 17/50
# 50/50 [==============================] - 3s 55ms/step - loss: 10.9036 - accuracy: 0.6881
# Epoch 18/50
# 50/50 [==============================] - 3s 54ms/step - loss: 10.8578 - accuracy: 0.6843
# Epoch 19/50
# 50/50 [==============================] - 3s 56ms/step - loss: 10.7675 - accuracy: 0.6944
# Epoch 20/50
# 50/50 [==============================] - 3s 56ms/step - loss: 10.6629 - accuracy: 0.7424
# Epoch 21/50
# 50/50 [==============================] - 3s 55ms/step - loss: 10.5419 - accuracy: 0.7929
# Epoch 22/50
# 50/50 [==============================] - 3s 55ms/step - loss: 10.5119 - accuracy: 0.7740
# Epoch 23/50
# 50/50 [==============================] - 3s 55ms/step - loss: 10.4569 - accuracy: 0.7715
# Epoch 24/50
# 50/50 [==============================] - 3s 56ms/step - loss: 10.3985 - accuracy: 0.8043
# Epoch 25/50
# 50/50 [==============================] - 3s 55ms/step - loss: 10.3551 - accuracy: 0.7891
# Epoch 26/50
# 50/50 [==============================] - 3s 55ms/step - loss: 10.3321 - accuracy: 0.8144
# Epoch 27/50
# 50/50 [==============================] - 3s 54ms/step - loss: 10.2684 - accuracy: 0.8245
# Epoch 28/50
# 50/50 [==============================] - 3s 55ms/step - loss: 10.2100 - accuracy: 0.8270
# Epoch 29/50
# 50/50 [==============================] - 3s 56ms/step - loss: 10.2031 - accuracy: 0.8283
# Epoch 30/50
# 50/50 [==============================] - 3s 54ms/step - loss: 10.1401 - accuracy: 0.8308
# Epoch 31/50
# 50/50 [==============================] - 3s 55ms/step - loss: 10.0480 - accuracy: 0.8636
# Epoch 32/50
# 50/50 [==============================] - 3s 54ms/step - loss: 10.0281 - accuracy: 0.8586
# Epoch 33/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.9674 - accuracy: 0.8649
# Epoch 34/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.9645 - accuracy: 0.8624
# Epoch 35/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.9367 - accuracy: 0.8737
# Epoch 36/50
# 50/50 [==============================] - 3s 54ms/step - loss: 9.8879 - accuracy: 0.8750
# Epoch 37/50
# 50/50 [==============================] - 3s 54ms/step - loss: 9.8193 - accuracy: 0.8965
# Epoch 38/50
# 50/50 [==============================] - 3s 57ms/step - loss: 9.8285 - accuracy: 0.8725
# Epoch 39/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.7948 - accuracy: 0.8750
# Epoch 40/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.7653 - accuracy: 0.8902
# Epoch 41/50
# 50/50 [==============================] - 3s 54ms/step - loss: 9.6938 - accuracy: 0.9154
# Epoch 42/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.7179 - accuracy: 0.8977
# Epoch 43/50
# 50/50 [==============================] - 3s 56ms/step - loss: 9.6849 - accuracy: 0.8914
# Epoch 44/50
# 50/50 [==============================] - 3s 54ms/step - loss: 9.6773 - accuracy: 0.9104
# Epoch 45/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.6496 - accuracy: 0.9003
# Epoch 46/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.5651 - accuracy: 0.9242
# Epoch 47/50
# 50/50 [==============================] - 3s 56ms/step - loss: 9.5073 - accuracy: 0.9394
# Epoch 48/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.5805 - accuracy: 0.9040
# Epoch 49/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.4908 - accuracy: 0.9306
# Epoch 50/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.4579 - accuracy: 0.9230
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_28 (Conv2D)          (None, 244, 244, 32)      320
#
#  max_pooling2d_28 (MaxPooli  (None, 122, 122, 32)      0
#  ng2D)
#
#  dropout_35 (Dropout)        (None, 122, 122, 32)      0
#
#  conv2d_29 (Conv2D)          (None, 122, 122, 64)      18496
#
#  max_pooling2d_29 (MaxPooli  (None, 61, 61, 64)        0
#  ng2D)
#
#  dropout_36 (Dropout)        (None, 61, 61, 64)        0
#
#  conv2d_30 (Conv2D)          (None, 61, 61, 128)       73856
#
#  max_pooling2d_30 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  dropout_37 (Dropout)        (None, 30, 30, 128)       0
#
#  conv2d_31 (Conv2D)          (None, 30, 30, 256)       295168
#
#  max_pooling2d_31 (MaxPooli  (None, 15, 15, 256)       0
#  ng2D)
#
#  dropout_38 (Dropout)        (None, 15, 15, 256)       0
#
#  flatten_7 (Flatten)         (None, 57600)             0
#
#  dense_14 (Dense)            (None, 512)               29491712
#
#  dropout_39 (Dropout)        (None, 512)               0
#
#  dense_15 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 50/50 [==============================] - 5s 60ms/step - loss: 22.6555 - accuracy: 0.0530
# Epoch 2/50
# 50/50 [==============================] - 3s 57ms/step - loss: 8.4877 - accuracy: 0.2462
# Epoch 3/50
# 50/50 [==============================] - 3s 57ms/step - loss: 6.7628 - accuracy: 0.4255
# Epoch 4/50
# 50/50 [==============================] - 3s 57ms/step - loss: 5.6393 - accuracy: 0.5379
# Epoch 5/50
# 50/50 [==============================] - 3s 58ms/step - loss: 4.8514 - accuracy: 0.6174
# Epoch 6/50
# 50/50 [==============================] - 3s 58ms/step - loss: 4.2486 - accuracy: 0.6742
# Epoch 7/50
# 50/50 [==============================] - 3s 57ms/step - loss: 3.8932 - accuracy: 0.6919
# Epoch 8/50
# 50/50 [==============================] - 3s 57ms/step - loss: 3.4694 - accuracy: 0.7222
# Epoch 9/50
# 50/50 [==============================] - 3s 57ms/step - loss: 3.2040 - accuracy: 0.7500
# Epoch 10/50
# 50/50 [==============================] - 3s 59ms/step - loss: 2.8914 - accuracy: 0.7879
# Epoch 11/50
# 50/50 [==============================] - 3s 57ms/step - loss: 2.7993 - accuracy: 0.7753
# Epoch 12/50
# 50/50 [==============================] - 3s 57ms/step - loss: 2.5491 - accuracy: 0.7854
# Epoch 13/50
# 50/50 [==============================] - 3s 57ms/step - loss: 2.4178 - accuracy: 0.7955
# Epoch 14/50
# 50/50 [==============================] - 3s 59ms/step - loss: 2.2048 - accuracy: 0.8422
# Epoch 15/50
# 50/50 [==============================] - 3s 58ms/step - loss: 2.1239 - accuracy: 0.8270
# Epoch 16/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.9444 - accuracy: 0.8510
# Epoch 17/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.8937 - accuracy: 0.8396
# Epoch 18/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.7391 - accuracy: 0.8598
# Epoch 19/50
# 50/50 [==============================] - 3s 59ms/step - loss: 1.8015 - accuracy: 0.8460
# Epoch 20/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.6805 - accuracy: 0.8548
# Epoch 21/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.6453 - accuracy: 0.8535
# Epoch 22/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.5854 - accuracy: 0.8788
# Epoch 23/50
# 50/50 [==============================] - 3s 59ms/step - loss: 1.4463 - accuracy: 0.8977
# Epoch 24/50
# 50/50 [==============================] - 3s 58ms/step - loss: 1.5150 - accuracy: 0.8838
# Epoch 25/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.4616 - accuracy: 0.8876
# Epoch 26/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.4176 - accuracy: 0.8851
# Epoch 27/50
# 50/50 [==============================] - 3s 58ms/step - loss: 1.3750 - accuracy: 0.8801
# Epoch 28/50
# 50/50 [==============================] - 3s 59ms/step - loss: 1.3608 - accuracy: 0.8990
# Epoch 29/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.3181 - accuracy: 0.9154
# Epoch 30/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.2948 - accuracy: 0.8952
# Epoch 31/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.2867 - accuracy: 0.9003
# Epoch 32/50
# 50/50 [==============================] - 3s 60ms/step - loss: 1.2503 - accuracy: 0.9205
# Epoch 33/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.2295 - accuracy: 0.9066
# Epoch 34/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.2762 - accuracy: 0.8826
# Epoch 35/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.2495 - accuracy: 0.8939
# Epoch 36/50
# 50/50 [==============================] - 3s 58ms/step - loss: 1.1586 - accuracy: 0.9129
# Epoch 37/50
# 50/50 [==============================] - 3s 58ms/step - loss: 1.2975 - accuracy: 0.8952
# Epoch 38/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.2123 - accuracy: 0.9129
# Epoch 39/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.1312 - accuracy: 0.9230
# Epoch 40/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.1517 - accuracy: 0.9116
# Epoch 41/50
# 50/50 [==============================] - 3s 59ms/step - loss: 1.1686 - accuracy: 0.9066
# Epoch 42/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.2249 - accuracy: 0.9078
# Epoch 43/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.0944 - accuracy: 0.9293
# Epoch 44/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.1367 - accuracy: 0.9091
# Epoch 45/50
# 50/50 [==============================] - 3s 59ms/step - loss: 1.0830 - accuracy: 0.9331
# Epoch 46/50
# 50/50 [==============================] - 3s 58ms/step - loss: 1.0565 - accuracy: 0.9242
# Epoch 47/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.1700 - accuracy: 0.9078
# Epoch 48/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.1861 - accuracy: 0.9205
# Epoch 49/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.0714 - accuracy: 0.9343
# Epoch 50/50
# 50/50 [==============================] - 3s 58ms/step - loss: 1.0440 - accuracy: 0.9318
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_32 (Conv2D)          (None, 244, 244, 32)      320
#
#  max_pooling2d_32 (MaxPooli  (None, 122, 122, 32)      0
#  ng2D)
#
#  dropout_40 (Dropout)        (None, 122, 122, 32)      0
#
#  conv2d_33 (Conv2D)          (None, 122, 122, 64)      18496
#
#  max_pooling2d_33 (MaxPooli  (None, 61, 61, 64)        0
#  ng2D)
#
#  dropout_41 (Dropout)        (None, 61, 61, 64)        0
#
#  conv2d_34 (Conv2D)          (None, 61, 61, 128)       73856
#
#  max_pooling2d_34 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  dropout_42 (Dropout)        (None, 30, 30, 128)       0
#
#  conv2d_35 (Conv2D)          (None, 30, 30, 256)       295168
#
#  max_pooling2d_35 (MaxPooli  (None, 15, 15, 256)       0
#  ng2D)
#
#  dropout_43 (Dropout)        (None, 15, 15, 256)       0
#
#  flatten_8 (Flatten)         (None, 57600)             0
#
#  dense_16 (Dense)            (None, 512)               29491712
#
#  dropout_44 (Dropout)        (None, 512)               0
#
#  dense_17 (Dense)            (None, 99)                50787
#
# =================================================================
# Total params: 29930339 (114.18 MB)
# Trainable params: 29930339 (114.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 50/50 [==============================] - 5s 57ms/step - loss: 29.2185 - accuracy: 0.0530
# Epoch 2/50
# 50/50 [==============================] - 3s 56ms/step - loss: 13.5775 - accuracy: 0.1970
# Epoch 3/50
# 50/50 [==============================] - 3s 56ms/step - loss: 12.9224 - accuracy: 0.2727
# Epoch 4/50
# 50/50 [==============================] - 3s 57ms/step - loss: 12.4692 - accuracy: 0.3788
# Epoch 5/50
# 50/50 [==============================] - 3s 56ms/step - loss: 12.0795 - accuracy: 0.4255
# Epoch 6/50
# 50/50 [==============================] - 3s 55ms/step - loss: 11.7772 - accuracy: 0.4747
# Epoch 7/50
# 50/50 [==============================] - 3s 55ms/step - loss: 11.6200 - accuracy: 0.4924
# Epoch 8/50
# 50/50 [==============================] - 3s 55ms/step - loss: 11.3996 - accuracy: 0.5631
# Epoch 9/50
# 50/50 [==============================] - 3s 57ms/step - loss: 11.2133 - accuracy: 0.5732
# Epoch 10/50
# 50/50 [==============================] - 3s 55ms/step - loss: 11.0862 - accuracy: 0.5821
# Epoch 11/50
# 50/50 [==============================] - 3s 55ms/step - loss: 10.9471 - accuracy: 0.6023
# Epoch 12/50
# 50/50 [==============================] - 3s 55ms/step - loss: 10.7659 - accuracy: 0.6301
# Epoch 13/50
# 50/50 [==============================] - 3s 56ms/step - loss: 10.7402 - accuracy: 0.6376
# Epoch 14/50
# 50/50 [==============================] - 3s 56ms/step - loss: 10.6003 - accuracy: 0.6490
# Epoch 15/50
# 50/50 [==============================] - 3s 55ms/step - loss: 10.4602 - accuracy: 0.6856
# Epoch 16/50
# 50/50 [==============================] - 3s 55ms/step - loss: 10.3612 - accuracy: 0.6919
# Epoch 17/50
# 50/50 [==============================] - 3s 55ms/step - loss: 10.2917 - accuracy: 0.7008
# Epoch 18/50
# 50/50 [==============================] - 3s 57ms/step - loss: 10.1913 - accuracy: 0.7096
# Epoch 19/50
# 50/50 [==============================] - 3s 55ms/step - loss: 10.0500 - accuracy: 0.7348
# Epoch 20/50
# 50/50 [==============================] - 3s 55ms/step - loss: 10.0386 - accuracy: 0.7412
# Epoch 21/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.9269 - accuracy: 0.7551
# Epoch 22/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.8299 - accuracy: 0.7626
# Epoch 23/50
# 50/50 [==============================] - 3s 56ms/step - loss: 9.7481 - accuracy: 0.7765
# Epoch 24/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.7053 - accuracy: 0.7639
# Epoch 25/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.6574 - accuracy: 0.7689
# Epoch 26/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.5659 - accuracy: 0.7854
# Epoch 27/50
# 50/50 [==============================] - 3s 56ms/step - loss: 9.4314 - accuracy: 0.8081
# Epoch 28/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.4163 - accuracy: 0.8068
# Epoch 29/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.3133 - accuracy: 0.8194
# Epoch 30/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.2756 - accuracy: 0.8182
# Epoch 31/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.2873 - accuracy: 0.7854
# Epoch 32/50
# 50/50 [==============================] - 3s 56ms/step - loss: 9.1155 - accuracy: 0.8308
# Epoch 33/50
# 50/50 [==============================] - 3s 55ms/step - loss: 9.1176 - accuracy: 0.8232
# Epoch 34/50
# 50/50 [==============================] - 3s 54ms/step - loss: 9.0315 - accuracy: 0.8333
# Epoch 35/50
# 50/50 [==============================] - 3s 55ms/step - loss: 8.9981 - accuracy: 0.8119
# Epoch 36/50
# 50/50 [==============================] - 3s 55ms/step - loss: 8.9239 - accuracy: 0.8295
# Epoch 37/50
# 50/50 [==============================] - 3s 57ms/step - loss: 8.8380 - accuracy: 0.8460
# Epoch 38/50
# 50/50 [==============================] - 3s 55ms/step - loss: 8.7539 - accuracy: 0.8523
# Epoch 39/50
# 50/50 [==============================] - 3s 55ms/step - loss: 8.7051 - accuracy: 0.8649
# Epoch 40/50
# 50/50 [==============================] - 3s 55ms/step - loss: 8.7361 - accuracy: 0.8333
# Epoch 41/50
# 50/50 [==============================] - 3s 56ms/step - loss: 8.6282 - accuracy: 0.8561
# Epoch 42/50
# 50/50 [==============================] - 3s 56ms/step - loss: 8.5330 - accuracy: 0.8775
# Epoch 43/50
# 50/50 [==============================] - 3s 55ms/step - loss: 8.5130 - accuracy: 0.8775
# Epoch 44/50
# 50/50 [==============================] - 3s 55ms/step - loss: 8.4619 - accuracy: 0.8712
# Epoch 45/50
# 50/50 [==============================] - 3s 55ms/step - loss: 8.3949 - accuracy: 0.8889
# Epoch 46/50
# 50/50 [==============================] - 3s 57ms/step - loss: 8.3656 - accuracy: 0.8838
# Epoch 47/50
# 50/50 [==============================] - 3s 55ms/step - loss: 8.3290 - accuracy: 0.8813
# Epoch 48/50
# 50/50 [==============================] - 3s 55ms/step - loss: 8.2411 - accuracy: 0.8826
# Epoch 49/50
# 50/50 [==============================] - 3s 55ms/step - loss: 8.2158 - accuracy: 0.8876
# Epoch 50/50
# 50/50 [==============================] - 3s 56ms/step - loss: 8.1857 - accuracy: 0.8838
